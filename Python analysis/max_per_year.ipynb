# %%
import pandas as pd

# %%
df1 = pd.read_csv('DMIRep19-02/max_hela _tidsspannet/grönbäck_1874_2025_max.csv', index_col = 'year').drop(columns = 'Unnamed: 0')

df2 = pd.read_csv('DMIRep19-02/max_hela _tidsspannet/HammerOddeFyr_1874_2025_max.csv', index_col = 'year').drop(columns = 'Unnamed: 0')

df3 = pd.read_csv('DMIRep19-02/max_hela _tidsspannet/LivgardensKaserne_1874_2025_max.csv', index_col = 'year').drop(columns = 'Unnamed: 0')

df4 = pd.read_csv('DMIRep19-02/max_hela _tidsspannet/Nordby_1874_2025_max.csv', index_col = 'year').drop(columns = 'Unnamed: 0')

df5 = pd.read_csv('DMIRep19-02/max_hela _tidsspannet/StoreJyndevad_1920_2025_max.csv', index_col = 'year').drop(columns = 'Unnamed: 0')

df6 = pd.read_csv('DMIRep19-02/max_hela _tidsspannet/Vestervig_1874_2025_max.csv', index_col = 'year').drop(columns = 'Unnamed: 0')


df_1874 = pd.concat([df1, df2, df3, df4, df6], axis = 1)
df_ = pd.concat([df1, df2, df3, df4, df5, df6], axis = 1)
rem61 = df_[df_.index < 1961]
rem20= df_[df_.index < 1920]
df_20 = df_.drop(rem20.index, axis = 0)
df_ = df_.drop(rem61.index, axis = 0)

df_1874
# Out:
#       precipitation  precipitation  precipitation  precipitation  \
# year
# 1874          24.10           15.8          18.40           35.8
# 1875          33.80           23.7          22.70           27.9
# 1876          26.50           26.3          15.50           28.5
# 1877          35.20           17.2          25.60           20.4
# 1878          32.20           37.5          24.30           37.2
# ...             ...            ...            ...            ...
# 2021          27.32           61.2          42.63           30.7
# 2022          36.72           21.7          27.51           20.8
# 2023          32.18           43.9          46.00           26.9
# 2024          28.00           33.6          26.00           97.6
# 2025          27.60           31.6          35.50           34.7
#
#       precipitation
# year
# 1874           24.2
# 1875           21.8
# 1876           14.0
# 1877           42.2
# 1878           24.4
# ...             ...
# 2021           49.1
# ...

# %%
df7 = pd.read_csv('DMIRep19-02/max_hela _tidsspannet/Aggersund_max.csv', index_col = 'Unnamed: 0')
df8 = pd.read_csv('DMIRep19-02/max_hela _tidsspannet/Båring_max.csv', index_col = 'Unnamed: 0')
df9 = pd.read_csv('DMIRep19-02/max_hela _tidsspannet/Erslev_max.csv', index_col = 'Unnamed: 0')
df10 = pd.read_csv('DMIRep19-02/max_hela _tidsspannet/Grönbjerg_max.csv', index_col = 'Unnamed: 0')
df11 = pd.read_csv('DMIRep19-02/max_hela _tidsspannet/Hajstrup_max.csv', index_col = 'Unnamed: 0')
df12 = pd.read_csv('DMIRep19-02/max_hela _tidsspannet/Juelsberg_max.csv', index_col = 'Unnamed: 0')
df13 = pd.read_csv('DMIRep19-02/max_hela _tidsspannet/Neble_max.csv', index_col = 'Unnamed: 0')
df14 = pd.read_csv('DMIRep19-02/max_hela _tidsspannet/NörreVorupör_max.csv', index_col = 'Unnamed: 0')
df15 = pd.read_csv('DMIRep19-02/max_hela _tidsspannet/Rangstrup_max.csv', index_col = 'Unnamed: 0')


df = pd.concat([df_, df7, df8, df9, df10, df11, df12, df13, df14, df15], axis = 1)
df = df.max(axis = 1)
df20 = df_20.max(axis = 1)
df.to_csv('Färdig_data_fler_punkter.csv')
df20.to_csv('Block_maxima_1920_2025.csv')
df_1874.max(axis = 1).to_csv('Block_maxima_1874_2025.csv')
# Out:
#       precipitation  precipitation  precipitation  precipitation  \
# 1961          22.70           50.5          22.90           37.1
# 1962          22.00           25.0          19.20           24.8
# 1963          43.40           31.0          35.20           43.3
# 1964          34.00           16.8          21.50           24.2
# 1965          24.50           40.7          37.40           32.1
# ...             ...            ...            ...            ...
# 2021          27.32           61.2          42.63           30.7
# 2022          36.72           21.7          27.51           20.8
# 2023          32.18           43.9          46.00           26.9
# 2024          28.00           33.6          26.00           97.6
# 2025          27.60           31.6          35.50           34.7
#
#       precipitation  precipitation    val    val    val    val    val    val  \
# 1961           26.4           37.3  64.80  18.50  16.40  44.10  24.50  22.00
# ...

# %%
df.plot()
# Out:
# <Axes: >
