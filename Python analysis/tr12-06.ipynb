# %%
import pandas as pd
import numpy as np
df = pd.read_csv('max24h_year.csv', sep = ';', )
#idx = np.r_[2:91]
#df.drop(df.columns[idx], axis = 1, inplace = True)
#df = df.dropna().reset_index()

df
# Out:
#     stataut  statman  1872  1873  1874  1875  1876  1877  1878  1879  ...  \
# 0      5005    20030   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1      5009    20055   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2      5015    20085   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3      5070    20670   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4      5085    20400   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5      5089    21020   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 6      5095    21080   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7      5105    21120   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8      5109    21160   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9      5135    21430   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10     5140    22020   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11     5150    22080   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
df.iloc[0].to_csv('tr12-06_1960-2011/Uggeby_5005.csv')
df.iloc[1].to_csv('tr12-06_1960-2011/Aggersund.csv')
df.iloc[2].to_csv('tr12-06_1960-2011/NorreVurpör.csv')
df.iloc[3].to_csv('tr12-06_1960-2011/Erslev.csv')
df.iloc[4].to_csv('tr12-06_1960-2011/Junget.csv')
df.iloc[7].to_csv('tr12-06_1960-2011/Hov.csv')
df.iloc[8].to_csv('tr12-06_1960-2011/Grönberg.csv')
df.iloc[9].to_csv('tr12-06_1960-2011/Rangstrup.csv')
df.iloc[10].to_csv('tr12-06_1960-2011/Hajstrup.csv')
df.iloc[11].to_csv('tr12-06_1960-2011/Båring.csv')
df.iloc[12].to_csv('tr12-06_1960-2011/Juelsberg.csv')
df.iloc[14].to_csv('tr12-06_1960-2011/Neble.csv')
