# %%
library(extRemes)
source("prob_ratio_gmst.r")

# %% [markdown]
# * Ladda in datamängderna

# %%
# Ladda in alla dataset och lägga in gmst i dem, 
# göra "under-sets" utan inkludering av 2024
gmst <- read.csv("/Users/joel/Livet/Globala System/År 3/LP 3/Kandidatarbete/Newell-Matthew-CCDetectonAttribution_Esbjerg-ac778b5/files/Rx1day-files/annual_sampling/observations/gmst/GMST_anomalies.csv", col.names = c("year", "GMST"), sep = ";", header = TRUE)
setwd("/Users/joel/Livet/Globala System/År 3/LP 3/Kandidatarbete/Kandidatarbete kod/Analyser mapp/Färdiga resultat")

df_C <- read.csv("Färdig_data_fler_punkter.csv") # 1961 data
df_B <- read.csv("data_1920_2025.csv") # 1920 data
df_A <- read.csv("Block_maxima_1874_2025.csv") # 1874 data
df_Nordby <- read.csv("Nordby_1874_2025_max.csv") # Nordby data

df_C1 <- merge(df_C, gmst, by = "year")
df_C2 <- df_C1[df_C1$year <= 2023, ] 

df_B1 <- merge(df_B, gmst, by = "year")
df_B2 <- df_B1[df_B1$year <= 2023, ] 

df_A1 <- merge(df_A, gmst, by = "year")
df_A2 <- df_A1[df_A1$year <= 2023, ]

df_A2_1920 <- df_A2[df_A2$year >= 1920, ] 
df_A2_1961 <- df_A2[df_A2$year >= 1961, ] 

df_Nordby<- df_Nordby[, -1]
df_Nordby1 <- merge(df_Nordby, gmst, by = "year")
df_Nordby2 <- df_Nordby1[df_Nordby1$year <= 2023, ]

# %% [markdown]
# * Stationära modeller:

# %%
mdl_A1_stat <- fevd(rain, 
                 data = df_A1, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_stat <- fevd(rain, 
                 data = df_A2, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )


mdl_A2_1874_stat <- fevd(rain, 
                 data = df_A2_1874, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_1961_stat <- fevd(rain, 
                 data = df_A2_1961, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_B1_stat <- fevd(rain, 
                 data = df_B1, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_B2_stat <- fevd(rain, 
                 data = df_B2, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_C1_stat <- fevd(rain, 
                 data = df_C1, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_C2_stat <- fevd(rain, 
                 data = df_C2, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_Nordby1_stat <- fevd(rain, 
                 data = df_Nordby1, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_Nordby2_stat <- fevd(rain, 
                 data = df_Nordby2, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# %% [markdown]
# * Linjära trender i mu

# %%
mdl_A1_1 <- fevd(rain, 
                 data = df_A1, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_1 <- fevd(rain, 
                 data = df_A2, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_1920_1 <- fevd(rain, 
                 data = df_A2_1920, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_1961_1 <- fevd(rain, 
                 data = df_A2_1961, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# Data B

mdl_B1_1 <- fevd(rain, 
                 data = df_B1, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_B2_1 <- fevd(rain, 
                 data = df_B2, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# Data C


mdl_C1_1 <- fevd(rain, 
                 data = df_C1, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_C2_1 <- fevd(rain, 
                 data = df_C2, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_Nordby1_1 <- fevd(rain, 
                 data = df_Nordby1, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_Nordby2_1 <- fevd(rain, 
                 data = df_Nordby2, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# %% [markdown]
# * Exponentiella trender i sigma

# %%
mdl_A1_2 <- fevd(rain, 
                 data = df_A1, 
                 scale.fun = ~GMST,
                 use.phi = TRUE,
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_2 <- fevd(rain, 
                 data = df_A2, 
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_1920_2 <- fevd(rain, 
                 data = df_A2_1920, 
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_1961_2 <- fevd(rain, 
                 data = df_A2_1961, 
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )


# Data B

mdl_B1_2 <- fevd(rain, 
                 data = df_B1, 
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_B2_2 <- fevd(rain, 
                 data = df_B2, 
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# Data C


mdl_C1_2 <- fevd(rain, 
                 data = df_C1, 
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_C2_2 <- fevd(rain, 
                 data = df_C2, 
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )


mdl_Nordby1_2 <- fevd(rain, 
                 data = df_Nordby1, 
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_Nordby2_2 <- fevd(rain, 
                 data = df_Nordby2, 
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# %% [markdown]
# * Linjära trender i mu och exponentiella trender i sigma

# %%
mdl_A1_3 <- fevd(rain, 
                 data = df_A1, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE,
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_3 <- fevd(rain, 
                 data = df_A2, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_1920_3 <- fevd(rain, 
                 data = df_A2_1920, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_1961_3 <- fevd(rain, 
                 data = df_A2_1961, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )


# Data B

mdl_B1_3 <- fevd(rain, 
                 data = df_B1, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_B2_3 <- fevd(rain, 
                 data = df_B2, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# Data C


mdl_C1_3 <- fevd(rain, 
                 data = df_C1, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_C2_3 <- fevd(rain, 
                 data = df_C2, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_Nordby1_3 <- fevd(rain, 
                 data = df_Nordby1, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_Nordby2_3 <- fevd(rain, 
                 data = df_Nordby2, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# %% [markdown]
# * Beräknar p-värden för alla modeller, jämfört med sina respektive stationära

# %%
cat("\nP-värden 1, 2 och 3 motsvarar trendmodellerna.\n")

cat("\nP-värde dataset A med 2024:")
lr.test(mdl_A1_stat, mdl_A1_1)$p.value
lr.test(mdl_A1_stat, mdl_A1_2)$p.value
lr.test(mdl_A1_stat, mdl_A1_3)$p.value

cat("\nP-värde dataset A utan 2024:")
lr.test(mdl_A2_stat, mdl_A2_1)$p.value
lr.test(mdl_A2_stat, mdl_A2_2)$p.value
lr.test(mdl_A2_stat, mdl_A2_3)$p.value

cat("\nP-värde dataset B med 2024:")
lr.test(mdl_B1_stat, mdl_B1_1)$p.value
lr.test(mdl_B1_stat, mdl_B1_2)$p.value
lr.test(mdl_B1_stat, mdl_B1_3)$p.value

cat("\nP-värde dataset B utan 2024:")
lr.test(mdl_B2_stat, mdl_B2_1)$p.value
lr.test(mdl_B2_stat, mdl_B2_2)$p.value
lr.test(mdl_B2_stat, mdl_B2_3)$p.value

cat("\nP-värde dataset C med 2024:")
lr.test(mdl_C1_stat, mdl_C1_1)$p.value
lr.test(mdl_C1_stat, mdl_C1_2)$p.value
lr.test(mdl_C1_stat, mdl_C1_3)$p.value

cat("\nP-värde dataset C utan 2024:")
lr.test(mdl_C2_stat, mdl_C2_1)$p.value
lr.test(mdl_C2_stat, mdl_C2_2)$p.value
lr.test(mdl_C2_stat, mdl_C2_3)$p.value

cat("\nP-värde dataset Nordby med 2024:")
lr.test(mdl_Nordby1_stat, mdl_Nordby1_1)$p.value
lr.test(mdl_Nordby1_stat, mdl_Nordby1_2)$p.value
lr.test(mdl_Nordby1_stat, mdl_Nordby1_3)$p.value

cat("\nP-värde dataset Nordby utan 2024:")
lr.test(mdl_Nordby2_stat, mdl_Nordby2_1)$p.value
lr.test(mdl_Nordby2_stat, mdl_Nordby2_2)$p.value
lr.test(mdl_Nordby2_stat, mdl_Nordby2_3)$p.value

cat("\nP-värde dataset A modell trend mu och sigma, dataset start 1920/1961:")
lr.test(mdl_A2_1874_stat, mdl_A2_1874_3)$p.value
lr.test(mdl_A2_1961_stat, mdl_A2_1961_3)$p.value
# Out:
# P-värden 1, 2 och 3 motsvarar trendmodellerna.
#
# P-värde dataset A med 2024:
# Likelihood-ratio
#        0.2199344
# Likelihood-ratio
#         0.824534
# Likelihood-ratio
#        0.2974211
# P-värde dataset A utan 2024:
# Likelihood-ratio
#         0.261759
# Likelihood-ratio
#         0.846055
# Likelihood-ratio
#        0.4840769
# P-värde dataset B med 2024:
# Likelihood-ratio
#        0.1461821
# Likelihood-ratio
#        0.3774859
# Likelihood-ratio
#        0.3271658
# P-värde dataset B utan 2024:
# Likelihood-ratio
#         0.179897
# Likelihood-ratio
#        0.1971085
# Likelihood-ratio
#        0.2894009
# P-värde dataset C med 2024:
# Likelihood-ratio
#         0.109682
# Likelihood-ratio
#        0.9921712
# Likelihood-ratio
#        0.2136563
# P-värde dataset C utan 2024:
# Likelihood-ratio
#        0.1366698
# Likelihood-ratio
#        0.7283578
# Likelihood-ratio
#        0.3139468
# P-värde dataset Nordby med 2024:
# Likelihood-ratio
#        0.1061245
# ...

# %%
A1_1_97.6_1874 = prob_ratio_gmst(mdl_A1_1, 2024, 1874, 97.6, gmst, TRUE)
A1_2_97.6_1874 = prob_ratio_gmst(mdl_A1_2, 2024, 1874, 97.6, gmst, TRUE)
A1_3_97.6_1874 = prob_ratio_gmst(mdl_A1_3, 2024, 1874, 97.6, gmst, TRUE)

A1_1_97.6_1961 = prob_ratio_gmst(mdl_A1_1, 2024, 1961, 97.6, gmst, TRUE)
A1_2_97.6_1961 = prob_ratio_gmst(mdl_A1_2, 2024, 1961, 97.6, gmst, TRUE)
A1_3_97.6_1961 = prob_ratio_gmst(mdl_A1_3, 2024, 1961, 97.6, gmst, TRUE)

A2_1_97.6_1874 = prob_ratio_gmst(mdl_A2_1, 2024, 1874, 97.6, gmst, TRUE)
A2_2_97.6_1874 = prob_ratio_gmst(mdl_A2_2, 2024, 1874, 97.6, gmst, TRUE)
A2_3_97.6_1874 = prob_ratio_gmst(mdl_A2_3, 2024, 1874, 97.6, gmst, TRUE)

A2_1_97.6_1961 = prob_ratio_gmst(mdl_A2_1, 2024, 1961, 97.6, gmst, TRUE)
A2_2_97.6_1961 = prob_ratio_gmst(mdl_A2_2, 2024, 1961, 97.6, gmst, TRUE)
A2_3_97.6_1961 = prob_ratio_gmst(mdl_A2_3, 2024, 1961, 97.6, gmst, TRUE)


A1_1_144.6_1874 = prob_ratio_gmst(mdl_A1_1, 2024, 1874, 144.6, gmst, TRUE)
A1_2_144.6_1874 = prob_ratio_gmst(mdl_A1_2, 2024, 1874, 144.6, gmst, TRUE)
A1_3_144.6_1874 = prob_ratio_gmst(mdl_A1_3, 2024, 1874, 144.6, gmst, TRUE)

A1_1_144.6_1961 = prob_ratio_gmst(mdl_A1_1, 2024, 1961, 144.6, gmst, TRUE)
A1_2_144.6_1961 = prob_ratio_gmst(mdl_A1_2, 2024, 1961, 144.6, gmst, TRUE)
A1_3_144.6_1961 = prob_ratio_gmst(mdl_A1_3, 2024, 1961, 144.6, gmst, TRUE)

A2_1_144.6_1874 = prob_ratio_gmst(mdl_A2_1, 2024, 1874, 144.6, gmst, TRUE)
A2_2_144.6_1874 = prob_ratio_gmst(mdl_A2_2, 2024, 1874, 144.6, gmst, TRUE)
A2_3_144.6_1874 = prob_ratio_gmst(mdl_A2_3, 2024, 1874, 144.6, gmst, TRUE)
A2_3_1920_144.6_1920 = prob_ratio_gmst(mdl_A2_1920_3, 2024, 1920, 144.6, gmst, TRUE)

A2_1_144.6_1961 = prob_ratio_gmst(mdl_A2_1, 2024, 1961, 144.6, gmst, TRUE)
A2_2_144.6_1961 = prob_ratio_gmst(mdl_A2_2, 2024, 1961, 144.6, gmst, TRUE)
A2_3_144.6_1961 = prob_ratio_gmst(mdl_A2_1961_3, 2024, 1961, 144.6, gmst, TRUE)
A2_3_1920_144.6_1961 = prob_ratio_gmst(mdl_A2_1920_3, 2024, 1961, 144.6, gmst, TRUE)
A2_3_1961_144.6_1961 = prob_ratio_gmst(mdl_A2_1961_3, 2024, 1961, 144.6, gmst, TRUE)


# Dataset B

B1_1_97.6_1920 = prob_ratio_gmst(mdl_B1_1, 2024, 1920, 97.6, gmst, TRUE)
B1_2_97.6_1920 = prob_ratio_gmst(mdl_B1_2, 2024, 1920, 97.6, gmst, TRUE)
B1_3_97.6_1920 = prob_ratio_gmst(mdl_B1_3, 2024, 1920, 97.6, gmst, TRUE)

B1_1_97.6_1961 = prob_ratio_gmst(mdl_B1_1, 2024, 1961, 97.6, gmst, TRUE)
B1_2_97.6_1961 = prob_ratio_gmst(mdl_B1_2, 2024, 1961, 97.6, gmst, TRUE)
B1_3_97.6_1961 = prob_ratio_gmst(mdl_B1_3, 2024, 1961, 97.6, gmst, TRUE)

B2_1_97.6_1920 = prob_ratio_gmst(mdl_B2_1, 2024, 1920, 97.6, gmst, TRUE)
B2_2_97.6_1920 = prob_ratio_gmst(mdl_B2_2, 2024, 1920, 97.6, gmst, TRUE)
B2_3_97.6_1920 = prob_ratio_gmst(mdl_B2_3, 2024, 1920, 97.6, gmst, TRUE)

B2_1_97.6_1961 = prob_ratio_gmst(mdl_B2_1, 2024, 1961, 97.6, gmst, TRUE)
B2_2_97.6_1961 = prob_ratio_gmst(mdl_B2_2, 2024, 1961, 97.6, gmst, TRUE)
B2_3_97.6_1961 = prob_ratio_gmst(mdl_B2_3, 2024, 1961, 97.6, gmst, TRUE)


B1_1_144.6_1920 = prob_ratio_gmst(mdl_B1_1, 2024, 1920, 144.6, gmst, TRUE)
B1_2_144.6_1920 = prob_ratio_gmst(mdl_B1_2, 2024, 1920, 144.6, gmst, TRUE)
B1_3_144.6_1920 = prob_ratio_gmst(mdl_B1_3, 2024, 1920, 144.6, gmst, TRUE)

B1_1_144.6_1961 = prob_ratio_gmst(mdl_B1_1, 2024, 1961, 144.6, gmst, TRUE)
B1_2_144.6_1961 = prob_ratio_gmst(mdl_B1_2, 2024, 1961, 144.6, gmst, TRUE)
B1_3_144.6_1961 = prob_ratio_gmst(mdl_B1_3, 2024, 1961, 144.6, gmst, TRUE)

B2_1_144.6_1920 = prob_ratio_gmst(mdl_B2_1, 2024, 1920, 144.6, gmst, TRUE)
B2_2_144.6_1920 = prob_ratio_gmst(mdl_B2_2, 2024, 1920, 144.6, gmst, TRUE)
B2_3_144.6_1920 = prob_ratio_gmst(mdl_B2_3, 2024, 1920, 144.6, gmst, TRUE)

B2_1_144.6_1961 = prob_ratio_gmst(mdl_B2_1, 2024, 1961, 144.6, gmst, TRUE)
B2_2_144.6_1961 = prob_ratio_gmst(mdl_B2_2, 2024, 1961, 144.6, gmst, TRUE)
B2_3_144.6_1961 = prob_ratio_gmst(mdl_B2_3, 2024, 1961, 144.6, gmst, TRUE)


# Dataset C

C1_1_97.6_1961 = prob_ratio_gmst(mdl_C1_1, 2024, 1961, 97.6, gmst, TRUE)
C1_2_97.6_1961 = prob_ratio_gmst(mdl_C1_2, 2024, 1961, 97.6, gmst, TRUE)
C1_3_97.6_1961 = prob_ratio_gmst(mdl_C1_3, 2024, 1961, 97.6, gmst, TRUE)

C2_1_97.6_1961 = prob_ratio_gmst(mdl_C2_1, 2024, 1961, 97.6, gmst, TRUE)
C2_2_97.6_1961 = prob_ratio_gmst(mdl_C2_2, 2024, 1961, 97.6, gmst, TRUE)
C2_3_97.6_1961 = prob_ratio_gmst(mdl_C2_3, 2024, 1961, 97.6, gmst, TRUE)

C1_1_144.6_1961 = prob_ratio_gmst(mdl_C1_1, 2024, 1961, 144.6, gmst, TRUE)
C1_2_144.6_1961 = prob_ratio_gmst(mdl_C1_2, 2024, 1961, 144.6, gmst, TRUE)
C1_3_144.6_1961 = prob_ratio_gmst(mdl_C1_3, 2024, 1961, 144.6, gmst, TRUE)

C2_stat_144.6_1961 = prob_ratio_gmst(mdl_C2_stat, 2024, 1961, 144.6, gmst, TRUE)
C2_1_144.6_1961 = prob_ratio_gmst(mdl_C2_1, 2024, 1961, 144.6, gmst, TRUE)
C2_2_144.6_1961 = prob_ratio_gmst(mdl_C2_2, 2024, 1961, 144.6, gmst, TRUE)
C2_3_144.6_1961 = prob_ratio_gmst(mdl_C2_3, 2024, 1961, 144.6, gmst, TRUE)

# Dataset Nordby 
Nordby1_1_97.6_1874 = prob_ratio_gmst(mdl_Nordby1_1, 2024, 1874, 97.6, gmst, TRUE)
Nordby1_2_97.6_1874 = prob_ratio_gmst(mdl_Nordby1_2, 2024, 1874, 97.6, gmst, TRUE)
Nordby1_3_97.6_1874 = prob_ratio_gmst(mdl_Nordby1_3, 2024, 1874, 97.6, gmst, TRUE)

Nordby1_1_97.6_1961 = prob_ratio_gmst(mdl_Nordby1_1, 2024, 1961, 97.6, gmst, TRUE)
Nordby1_2_97.6_1961 = prob_ratio_gmst(mdl_Nordby1_2, 2024, 1961, 97.6, gmst, TRUE)
Nordby1_3_97.6_1961 = prob_ratio_gmst(mdl_Nordby1_3, 2024, 1961, 97.6, gmst, TRUE)

Nordby2_1_97.6_1874 = prob_ratio_gmst(mdl_Nordby2_1, 2024, 1874, 97.6, gmst, TRUE)
Nordby2_2_97.6_1874 = prob_ratio_gmst(mdl_Nordby2_2, 2024, 1874, 97.6, gmst, TRUE)
Nordby2_3_97.6_1874 = prob_ratio_gmst(mdl_Nordby2_3, 2024, 1874, 97.6, gmst, TRUE)

Nordby2_1_97.6_1961 = prob_ratio_gmst(mdl_Nordby2_1, 2024, 1961, 97.6, gmst, TRUE)
Nordby2_2_97.6_1961 = prob_ratio_gmst(mdl_Nordby2_2, 2024, 1961, 97.6, gmst, TRUE)
Nordby2_3_97.6_1961 = prob_ratio_gmst(mdl_Nordby2_3, 2024, 1961, 97.6, gmst, TRUE)


Nordby1_1_144.6_1874 = prob_ratio_gmst(mdl_Nordby1_1, 2024, 1874, 144.6, gmst, TRUE)
Nordby1_2_144.6_1874 = prob_ratio_gmst(mdl_Nordby1_2, 2024, 1874, 144.6, gmst, TRUE)
Nordby1_3_144.6_1874 = prob_ratio_gmst(mdl_Nordby1_3, 2024, 1874, 144.6, gmst, TRUE)

Nordby1_1_144.6_1961 = prob_ratio_gmst(mdl_Nordby1_1, 2024, 1961, 144.6, gmst, TRUE)
Nordby1_2_144.6_1961 = prob_ratio_gmst(mdl_Nordby1_2, 2024, 1961, 144.6, gmst, TRUE)
Nordby1_3_144.6_1961 = prob_ratio_gmst(mdl_Nordby1_3, 2024, 1961, 144.6, gmst, TRUE)

Nordby2_1_144.6_1874 = prob_ratio_gmst(mdl_Nordby2_1, 2024, 1874, 144.6, gmst, TRUE)
Nordby2_2_144.6_1874 = prob_ratio_gmst(mdl_Nordby2_2, 2024, 1874, 144.6, gmst, TRUE)
Nordby2_3_144.6_1874 = prob_ratio_gmst(mdl_Nordby2_3, 2024, 1874, 144.6, gmst, TRUE)

Nordby2_1_144.6_1961 = prob_ratio_gmst(mdl_Nordby2_1, 2024, 1961, 144.6, gmst, TRUE)
Nordby2_2_144.6_1961 = prob_ratio_gmst(mdl_Nordby2_2, 2024, 1961, 144.6, gmst, TRUE)
Nordby2_3_144.6_1961 = prob_ratio_gmst(mdl_Nordby2_3, 2024, 1961, 144.6, gmst, TRUE)

# %%
options(scipen = 999)

# %% [markdown]
# * Kör prob_ratio_gmst med alla de datamängder, startår samt intensiteter vi är intresserade av

# %% [markdown]
# * Threshold 144.6, 2024 ej inkluderat

# %%
cat("Dataset A")
A2_1_144.6_1874
A2_1_144.6_1961
A2_2_144.6_1874
A2_2_144.6_1961
A2_3_144.6_1874
A2_3_144.6_1961



cat("--------------------------------------------------\nDataset B")
B2_1_144.6_1920
B2_1_144.6_1961
B2_2_144.6_1920
B2_2_144.6_1961
B2_3_144.6_1920
B2_3_144.6_1961

cat("--------------------------------------------------\nDataset C")
C2_1_144.6_1961
C2_2_144.6_1961
C2_3_144.6_1961

cat("--------------------------------------------------\nDataset Nordby")
Nordby2_1_144.6_1874
Nordby2_1_144.6_1961
Nordby2_2_144.6_1874
Nordby2_2_144.6_1961
Nordby2_3_144.6_1874
Nordby2_3_144.6_1961
# Out:
# Dataset A
# $type
# [1] "Dataset: df_A2, Threshold: 144.6, Year PR & I: 1874, 2024: No, Trend: mu, Kovariat: GMST"
#
# $P1
# [1] 0.0018209
#
# $P0
# [1] 0.00164252
#
# $PR
# [1] 1.1086
#
# $delta_I
# [1] 1.9673
#
# $Parametrar
# $Parametrar[[1]]
#      mu0
# 37.74912
#
# $Parametrar[[2]]
#     mu1
# 2.12268
#
# $Parametrar[[3]]
# log.scale
#  2.223851
#
# $Parametrar[[4]]
# [1] NA
#
# $Parametrar[[5]]
#     shape
# 0.1687866
# $type
# [1] "Dataset: df_A2, Threshold: 144.6, Year PR & I: 1961, 2024: No, Trend: mu, Kovariat: GMST"
#
# $P1
# [1] 0.0018209
#
# $P0
# [1] 0.00167995
#
# $PR
# [1] 1.0839
#
# $delta_I
# [1] 1.52784
#
# $Parametrar
# $Parametrar[[1]]
#      mu0
# 37.74912
#
# $Parametrar[[2]]
#     mu1
# 2.12268
#
# $Parametrar[[3]]
# log.scale
#  2.223851
#
# $Parametrar[[4]]
# [1] NA
#
# $Parametrar[[5]]
#     shape
# 0.1687866
# $type
# [1] "Dataset: df_A2, Threshold: 144.6, Year PR & I: 1874, 2024: No, Trend:  sigma, Kovariat: GMST"
#
# $P1
# [1] 0.00150877
#
# $P0
# ...

# %% [markdown]
# * Threshold 144.6, 2024 inkluderat

# %%
cat("Dataset A")
A1_1_144.6_1874
A1_1_144.6_1961
A1_2_144.6_1874
A1_2_144.6_1961
A1_3_144.6_1874
A1_3_144.6_1961

cat("--------------------------------------------------\nDataset B")
B1_1_144.6_1920
B1_1_144.6_1961
B1_2_144.6_1920
B1_2_144.6_1961
B1_3_144.6_1920
B1_3_144.6_1961

cat("--------------------------------------------------\nDataset C")
C1_1_144.6_1961
C1_2_144.6_1961
C1_3_144.6_1961

cat("--------------------------------------------------\nDataset Nordby")
Nordby1_1_144.6_1874
Nordby1_1_144.6_1961
Nordby1_2_144.6_1874
Nordby1_2_144.6_1961
Nordby1_3_144.6_1874
Nordby1_3_144.6_1961
# Out:
# Dataset A
# $type
# [1] "Dataset: df_A1, Threshold: 144.6, Year PR & I: 1874, 2024: Yes, Trend: mu, Kovariat: GMST"
#
# $P1
# [1] 0.0022946
#
# $P0
# [1] 0.0020619
#
# $PR
# [1] 1.11286
#
# $delta_I
# [1] 2.15077
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A1, Threshold: 144.6, Year PR & I: 1961, 2024: Yes, Trend: mu, Kovariat: GMST"
#
# $P1
# [1] 0.0022946
#
# $P0
# [1] 0.00211061
#
# $PR
# [1] 1.08717
#
# $delta_I
# [1] 1.66965
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A1, Threshold: 144.6, Year PR & I: 1874, 2024: Yes, Trend:  sigma, Kovariat: GMST"
#
# $P1
# [1] 0.00245293
#
# $P0
# [1] 0.00201652
#
# $PR
# [1] 1.21642
#
# $delta_I
# [1] 3.93374
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A1, Threshold: 144.6, Year PR & I: 1961, 2024: Yes, Trend:  sigma, Kovariat: GMST"
#
# $P1
# [1] 0.00245293
#
# $P0
# [1] 0.00210597
#
# $PR
# [1] 1.16475
#
# $delta_I
# [1] 3.06006
#
# $Parametrar
# [1] NA
# $type
# ...

# %% [markdown]
# * Threshold 97.6, 2024 ej inkluderat

# %%
cat("Dataset A")
A2_1_97.6_1874
A2_1_97.6_1961
A2_2_97.6_1874
A2_2_97.6_1961
A2_3_97.6_1874
A2_3_97.6_1961

cat("--------------------------------------------------\nDataset B")
B2_1_97.6_1920
B2_1_97.6_1961
B2_2_97.6_1920
B2_2_97.6_1961
B2_3_97.6_1920
B2_3_97.6_1961

cat("--------------------------------------------------\nDataset C")
C2_1_97.6_1961
C2_2_97.6_1961
C2_3_97.6_1961

cat("--------------------------------------------------\nDataset Nordby")
Nordby2_1_97.6_1874
Nordby2_1_97.6_1961
Nordby2_2_97.6_1874
Nordby2_2_97.6_1961
Nordby2_3_97.6_1874
Nordby2_3_97.6_1961
# Out:
# Dataset A
# $type
# [1] "Dataset: df_A2, Threshold: 97.6, Year PR & I: 1874, 2024: No, Trend: mu, Kovariat: GMST"
#
# $P1
# [1] 0.01447243
#
# $P0
# [1] 0.01251835
#
# $PR
# [1] 1.1561
#
# $delta_I
# [1] 2.94255
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A2, Threshold: 97.6, Year PR & I: 1961, 2024: No, Trend: mu, Kovariat: GMST"
#
# $P1
# [1] 0.01447243
#
# $P0
# [1] 0.01292052
#
# $PR
# [1] 1.12011
#
# $delta_I
# [1] 2.28036
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A2, Threshold: 97.6, Year PR & I: 1874, 2024: No, Trend:  sigma, Kovariat: GMST"
#
# $P1
# [1] 0.0118374
#
# $P0
# [1] 0.01362028
#
# $PR
# [1] 0.8691
#
# $delta_I
# [1] -2.76524
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A2, Threshold: 97.6, Year PR & I: 1961, 2024: No, Trend:  sigma, Kovariat: GMST"
#
# $P1
# [1] 0.0118374
#
# $P0
# [1] 0.01320989
#
# $PR
# [1] 0.8961
#
# $delta_I
# [1] -2.15928
#
# $Parametrar
# [1] NA
# $type
# ...

# %% [markdown]
# * Threshold 97.6, 2024 inkluderat

# %%
cat("Dataset A")
A1_1_97.6_1874
A1_1_97.6_1961
A1_2_97.6_1874
A1_2_97.6_1961
A1_3_97.6_1874
A1_3_97.6_1961

cat("\n--------------------------------------------------\nDataset B\n")
B1_1_97.6_1920
B1_1_97.6_1961
B1_2_97.6_1920
B1_2_97.6_1961
B1_3_97.6_1920
B1_3_97.6_1961

cat("\n--------------------------------------------------\nDataset C\n")
C1_1_97.6_1961
C1_2_97.6_1961
C1_3_97.6_1961

cat("\n--------------------------------------------------\nDataset Nordby\n")
Nordby1_1_97.6_1874
Nordby1_1_97.6_1961
Nordby1_2_97.6_1874
Nordby1_2_97.6_1961
Nordby1_3_97.6_1874
Nordby1_3_97.6_1961
# Out:
# Dataset A
# $type
# [1] "Dataset: df_A1, Threshold: 97.6, Year PR & I: 1874, 2024: Yes, Trend: mu, Kovariat: GMST"
#
# $P1
# [1] 0.01661505
#
# $P0
# [1] 0.01427783
#
# $PR
# [1] 1.1637
#
# $delta_I
# [1] 3.21984
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A1, Threshold: 97.6, Year PR & I: 1961, 2024: Yes, Trend: mu, Kovariat: GMST"
#
# $P1
# [1] 0.01661505
#
# $P0
# [1] 0.01475704
#
# $PR
# [1] 1.12591
#
# $delta_I
# [1] 2.49374
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A1, Threshold: 97.6, Year PR & I: 1874, 2024: Yes, Trend:  sigma, Kovariat: GMST"
#
# $P1
# [1] 0.01667119
#
# $P0
# [1] 0.01429363
#
# $PR
# [1] 1.16634
#
# $delta_I
# [1] 3.22573
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A1, Threshold: 97.6, Year PR & I: 1961, 2024: Yes, Trend:  sigma, Kovariat: GMST"
#
# $P1
# [1] 0.01667119
#
# $P0
# [1] 0.01479094
#
# $PR
# [1] 1.12712
#
# $delta_I
# [1] 2.5131
#
# $Parametrar
# [1] NA
# $type
# ...

# %% [markdown]
# * Längd på dataset analysen

# %%
cat("Hur längd på dataset påverkar resultat:")
A2_3_1920_144.6_1920
A2_3_1920_144.6_1961
A2_3_1920_144.6_1920
A2_3_1961_144.6_1961
# Out:
# Hur längd på dataset påverkar resultat:
# $type
# [1] "Dataset: df_A2_1920, Threshold: 144.6, Year PR & I: 1920, 2024: No, Trend: mu sigma, Kovariat: GMST"
#
# $P1
# [1] 0.00235786
#
# $P0
# [1] 0.00055263
#
# $PR
# [1] 4.26663
#
# $delta_I
# [1] 26.44354
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A2_1920, Threshold: 144.6, Year PR & I: 1961, 2024: No, Trend: mu sigma, Kovariat: GMST"
#
# $P1
# [1] 0.00235786
#
# $P0
# [1] 0.00081668
#
# $PR
# [1] 2.88714
#
# $delta_I
# [1] 19.11387
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A2_1920, Threshold: 144.6, Year PR & I: 1920, 2024: No, Trend: mu sigma, Kovariat: GMST"
#
# $P1
# [1] 0.00235786
#
# $P0
# [1] 0.00055263
#
# $PR
# [1] 4.26663
#
# $delta_I
# [1] 26.44354
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A2_1961, Threshold: 144.6, Year PR & I: 1961, 2024: No, Trend: mu sigma, Kovariat: GMST"
#
# $P1
# [1] 0.00360427
#
# $P0
# [1] 0.00064354
#
# $PR
# [1] 5.60073
#
# $delta_I
# [1] 33.85242
#
# $Parametrar
# ...

# %% [markdown]
# * Gör QQ-plots

# %%
source("qq_file.r")

# %%
options(repr.plot.width = 10, repr.plot.height = 10)

par(mfrow = c(2,2))
qq_plot(mdl_Nordby2_stat)
qq_plot(mdl_Nordby2_1)
qq_plot(mdl_Nordby2_2)
qq_plot(mdl_Nordby2_3)

par(mfrow = c(2,2))
qq_plot(mdl_A2_stat)
qq_plot(mdl_A2_1)
qq_plot(mdl_A2_2)
qq_plot(mdl_A2_3)

par(mfrow = c(2,2))
qq_plot(mdl_B2_stat)
qq_plot(mdl_B2_1)
qq_plot(mdl_B2_2)
qq_plot(mdl_B2_3)

par(mfrow = c(2,2))
qq_plot(mdl_C2_stat)
qq_plot(mdl_C2_1)
qq_plot(mdl_C2_2)
qq_plot(mdl_C2_3)
# Out:
# Plot with title “QQ-plot
#  Trend i μ och σ”
# Plot with title “QQ-plot
#  Trend i μ och σ”
# Plot with title “QQ-plot
#  Trend i μ och σ”
# Plot with title “QQ-plot
#  Trend i μ och σ”
