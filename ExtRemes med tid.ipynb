# %%
library(extRemes)

# %% [markdown]
# * Ladda in datamängderna

# %%
# Ladda in alla dataset och göra "under-sets" utan inkludering av 2024

setwd("/Users/joel/Livet/Globala System/År 3/LP 3/Kandidatarbete/Kandidatarbete kod")

df_C <- read.csv("Färdig_data_fler_punkter.csv") # 1961 data
df_C$COV <- df_C$year - 1961

df_B <- read.csv("data_1920_2025.csv") # 1920 data
df_B$COV <- df_B$year - 1920

df_A <- read.csv("Block_maxima_1874_2025.csv") # 1874 data
df_A$COV <- df_A$year - 1874 

df_Nordby <- read.csv("Nordby_1874_2025_max.csv") # Nordby 1874 data

df_C1 <- df_C[df_C$year <= 2024, ] 
df_C2 <- df_C[df_C$year <= 2023, ] 

df_B1 <- df_B[df_B$year <= 2024, ] 
df_B2 <- df_B[df_B$year <= 2023, ] 

df_A1 <- df_A[df_A$year <= 2024, ] 
df_A2 <- df_A[df_A$year <= 2023, ] 

df_Nordby1 <- df_Nordby[df_Nordby$year <= 2024, ] 
df_Nordby2 <- df_Nordby[df_Nordby$year <= 2023, ]

# %% [markdown]
# * Stationär modell

# %%
mdl_A1_stat <- fevd(rain, 
                 data = df_A1, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                 use.phi = TRUE
                )

mdl_A2_stat <- fevd(rain, 
                 data = df_A2, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                 use.phi = TRUE
                )

mdl_B1_stat <- fevd(rain, 
                 data = df_B1, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                 use.phi = TRUE
                )

mdl_B2_stat <- fevd(rain, 
                 data = df_B2, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                 use.phi = TRUE
                )

mdl_C1_stat <- fevd(rain, 
                 data = df_C1, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                 use.phi = TRUE
                )

mdl_C2_stat <- fevd(rain, 
                 data = df_C2, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                 use.phi = TRUE
                )

mdl_Nordby1_stat <- fevd(rain, 
                 data = df_Nordby1, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                 use.phi = TRUE
                )

mdl_Nordby2_stat <- fevd(rain, 
                 data = df_Nordby2, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                 use.phi = TRUE
                )

# %% [markdown]
# * Modell med linjär trend i mu

# %%
mdl_A1_1 <- fevd(rain, 
                 data = df_A1, 
                 location.fun = ~COV, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                 use.phi = TRUE
                )

mdl_A2_1 <- fevd(rain, 
                 data = df_A2, 
                 location.fun = ~COV, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                 use.phi = TRUE
                )

# Data B

mdl_B1_1 <- fevd(rain, 
                 data = df_B1, 
                 location.fun = ~COV, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                 use.phi = TRUE
                )

mdl_B2_1 <- fevd(rain, 
                 data = df_B2, 
                 location.fun = ~COV, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                 use.phi = TRUE
                )

# Data C


mdl_C1_1 <- fevd(rain, 
                 data = df_C1, 
                 location.fun = ~COV, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                 use.phi = TRUE
                )

mdl_C2_1 <- fevd(rain, 
                 data = df_C2, 
                 location.fun = ~COV, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                 use.phi = TRUE
                )

mdl_Nordby1_1 <- fevd(rain, 
                 data = df_Nordby1, 
                 location.fun = ~COV, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                 use.phi = TRUE
                )

mdl_Nordby2_1 <- fevd(rain, 
                 data = df_Nordby2, 
                 location.fun = ~COV, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                 use.phi = TRUE
                )

# %% [markdown]
# * Modell med exponentiell trend i sigma

# %%
mdl_A1_2 <- fevd(rain, 
                 data = df_A1, 
                 scale.fun = ~COV,
                 use.phi = TRUE,
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_2 <- fevd(rain, 
                 data = df_A2, 
                 scale.fun = ~COV,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# Data B

mdl_B1_2 <- fevd(rain, 
                 data = df_B1, 
                 scale.fun = ~COV,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_B2_2 <- fevd(rain, 
                 data = df_B2, 
                 scale.fun = ~COV,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# Data C


mdl_C1_2 <- fevd(rain, 
                 data = df_C1, 
                 scale.fun = ~COV,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_C2_2 <- fevd(rain, 
                 data = df_C2, 
                 scale.fun = ~COV,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_Nordby1_2 <- fevd(rain, 
                 data = df_Nordby1, 
                 scale.fun = ~COV,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_Nordby2_2 <- fevd(rain, 
                 data = df_Nordby2, 
                 scale.fun = ~COV,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# %% [markdown]
# * Modeller med linjära trender i mu och exponentiella i sigma

# %%
mdl_A1_3 <- fevd(rain, 
                 data = df_A1, 
                 location.fun = ~COV,
                 scale.fun = ~COV,
                 use.phi = TRUE,
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_3 <- fevd(rain, 
                 data = df_A2, 
                 location.fun = ~COV,
                 scale.fun = ~COV,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# Data B

mdl_B1_3 <- fevd(rain, 
                 data = df_B1, 
                 location.fun = ~COV,
                 scale.fun = ~COV,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_B2_3 <- fevd(rain, 
                 data = df_B2, 
                 location.fun = ~COV,
                 scale.fun = ~COV,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# Data C


mdl_C1_3 <- fevd(rain, 
                 data = df_C1, 
                 location.fun = ~COV,
                 scale.fun = ~COV,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_C2_3 <- fevd(rain, 
                 data = df_C2, 
                 location.fun = ~COV,
                 scale.fun = ~COV,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_Nordby1_3 <- fevd(rain, 
                 data = df_Nordby1, 
                 location.fun = ~COV,
                 scale.fun = ~COV,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_Nordby2_3 <- fevd(rain, 
                 data = df_Nordby2, 
                 location.fun = ~COV,
                 scale.fun = ~COV,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# %% [markdown]
# * Beräknar p-värden för alla modeller, jämfört med sina respektive stationära

# %%
cat("\nP-värden 1, 2 och 3 motsvarar trendmodellerna.\n")

cat("\nP-värde dataset A med 2024:")
lr.test(mdl_A1_stat, mdl_A1_1)$p.value
lr.test(mdl_A1_stat, mdl_A1_2)$p.value
lr.test(mdl_A1_stat, mdl_A1_3)$p.value

cat("\nP-värde dataset A utan 2024:")
lr.test(mdl_A2_stat, mdl_A2_1)$p.value
lr.test(mdl_A2_stat, mdl_A2_2)$p.value
lr.test(mdl_A2_stat, mdl_A2_3)$p.value

cat("\nP-värde dataset B med 2024:")
lr.test(mdl_B1_stat, mdl_B1_1)$p.value
lr.test(mdl_B1_stat, mdl_B1_2)$p.value
lr.test(mdl_B1_stat, mdl_B1_3)$p.value

cat("\nP-värde dataset B utan 2024:")
lr.test(mdl_B2_stat, mdl_B2_1)$p.value
lr.test(mdl_B2_stat, mdl_B2_2)$p.value
lr.test(mdl_B2_stat, mdl_B2_3)$p.value

cat("\nP-värde dataset C med 2024:")
lr.test(mdl_C1_stat, mdl_C1_1)$p.value
lr.test(mdl_C1_stat, mdl_C1_2)$p.value
lr.test(mdl_C1_stat, mdl_C1_3)$p.value

cat("\nP-värde dataset C utan 2024:")
lr.test(mdl_C2_stat, mdl_C2_1)$p.value
lr.test(mdl_C2_stat, mdl_C2_2)$p.value
lr.test(mdl_C2_stat, mdl_C2_3)$p.value

cat("\nP-värde dataset Nordby med 2024:")
lr.test(mdl_Nordby1_stat, mdl_Nordby1_1)$p.value
lr.test(mdl_Nordby1_stat, mdl_Nordby1_2)$p.value
lr.test(mdl_Nordby1_stat, mdl_Nordby1_3)$p.value

cat("\nP-värde dataset Nordby utan 2024:")
lr.test(mdl_Nordby2_stat, mdl_Nordby2_1)$p.value
lr.test(mdl_Nordby2_stat, mdl_Nordby2_2)$p.value
lr.test(mdl_Nordby2_stat, mdl_Nordby2_3)$p.value
# Out:
# P-värden 1, 2 och 3 motsvarar trendmodellerna.
#
# P-värde dataset A med 2024:
# Likelihood-ratio
#        0.2560008
# Likelihood-ratio
#        0.5283327
# Likelihood-ratio
#        0.5221766
# P-värde dataset A utan 2024:
# Likelihood-ratio
#        0.2883117
# Likelihood-ratio
#          0.37137
# Likelihood-ratio
#        0.5155718
# P-värde dataset B med 2024:
# Likelihood-ratio
#        0.1223871
# Likelihood-ratio
#       0.07471433
# Likelihood-ratio
#        0.1579945
# P-värde dataset B utan 2024:
# Likelihood-ratio
#        0.1421411
# Likelihood-ratio
#         0.042078
# Likelihood-ratio
#        0.1127904
# P-värde dataset C med 2024:
# Likelihood-ratio
#        0.1483418
# Likelihood-ratio
#        0.8645247
# Likelihood-ratio
#         0.257139
# P-värde dataset C utan 2024:
# Likelihood-ratio
#        0.1782035
# Likelihood-ratio
#        0.9328919
# Likelihood-ratio
#        0.3621224
# P-värde dataset Nordby med 2024:
# Likelihood-ratio
#        0.3746951
# ...

# %% [markdown]
# * Funktion för beräkning av PR och delta_I, som kan ge alla under-parametrar också om extra = TRUE

# %%
prob_ratio <- function(mdl, year_f, year_cf, x_val, extra = FALSE){

    # ladda in datan från modellen GEV-modellen
    df = mdl$cov.data

    # Hitta COV för year_f, 2024 finns inte alltid med i datamängden, så då tar vi COV för det sista året, och adderar mellanskillnaden
    # mellan year_f och datamängdens högsta årtal till COV.
    # detta måste göras då vårat startår har COV = 0, andra året har COV = 1, osv.
    if(year_f %in% df$year){
        cov_f <- df$COV[df$year == year_f]
    }  
    else {
        nearest_year <- max(df$year)
        cov_f <- df$COV[df$year == nearest_year] + (year_f - nearest_year)
    }
    
    # Hitta år för year_cf
    cov_cf <- df$COV[df$year == year_cf]

    # Kolla om 2024 är inkluderat i dataanpassningen
    if (2024 %in% mdl$cov.data$year) {
        inc_2024 <- "Yes"   
    }
    else {
        inc_2024 <- "No"
    }

    # Ta fram parametervärden för år f och cf, samt underliggande parametervärden
    trend = ""
    
    par <- mdl$results$par
    if("mu1" %in% names(par)) {
        mu_f  <- par["mu0"] + par["mu1"] * cov_f
        mu_cf <- par["mu0"] + par["mu1"] * cov_cf
        
        mu0 = par["mu0"]
        mu1 = par["mu1"]

        trend <- paste0(trend, "mu")
        
    } else {
        # Stationär mu
        mu_f = par["location"]
        mu_cf = par["location"]

        mu0 = par["location"]
        mu1 = NA
    }

    
    # Kolla om det finns trend i sigma
    if("phi1" %in% names(par)) {
        # Log-linjär trend i sigma (use.phi = TRUE)
        sigma_f  <- exp(par["phi0"] + par["phi1"] * cov_f)
        sigma_cf <- exp(par["phi0"] + par["phi1"] * cov_cf)

        phi0 = par["phi0"]
        phi1 = par["phi1"]

        trend <- paste(trend, "sigma")
        
    } else {
        sigma_f  <- exp(par["log.scale"])
        sigma_cf <- exp(par["log.scale"])

        phi0 = par["log.scale"]
        phi1 = NA

    }

    # beräknar överskridande sannolikheter för regnet med de givna parametervärdena
    prob_f <- 1 - pevd(x_val, 
                        loc = mu_f, 
                        scale = sigma_f, 
                        shape = par["shape"], 
                        type = "GEV")
    
    
    prob_cf <- 1 - pevd(x_val, 
                        loc = mu_cf, 
                        scale = sigma_cf, 
                        shape = par["shape"], 
                        type = "GEV")

    # Beräknar intensitet på ett regn med samma sannolikhet som 144.6 i 2024 för vårat year_cf
    I0 <- unname(qevd(1-prob_f,
           loc   = mu_cf,
           scale = sigma_cf,
           shape = par["shape"],
           type  = "GEV"))
    
    # Relativ intensitetsförändring
    delta_I <- ((x_val - I0)/I0 ) * 100

    # Probability ratio
    P0 = prob_cf
    P1 = prob_f
    
    PR = P1/P0

    # Gör en lista med alla parametrar för modellen
    sigma0 = sprintf("Sigma0: %s",exp(unname(phi0)))
    shape = par["shape"]
    pars = NA
    if (extra==TRUE){
        pars = list(mu0, mu1, sigma0, phi0, phi1, shape
            )
        }
    
    resultat = list("type" = sprintf("Dataset: %s, Threshold: %s, Year PR & I: %s, 2024: %s, Trend: %s, Kovariat: %s", mdl$data[2], x_val , year_cf, inc_2024, trend, "tid"),
    "P0" =  round(P0, 7), "P1" =  round(P1, 7), "PR"      = round(PR, 5),  
    "delta_I" = round(delta_I, 5), pars
)
    return(resultat)    
    }

# %%
options(scipen = 999)

# %% [markdown]
# * Kör prob_ratio med alla de datamängder, startår samt intensitet vi är intresserade av

# %%
A1_1_97.6_1874 = prob_ratio(mdl_A1_1, 2024, 1874, 97.6)
A1_2_97.6_1874 = prob_ratio(mdl_A1_2, 2024, 1874, 97.6)
A1_3_97.6_1874 = prob_ratio(mdl_A1_3, 2024, 1874, 97.6)

A1_1_97.6_1961 = prob_ratio(mdl_A1_1, 2024, 1961, 97.6)
A1_2_97.6_1961 = prob_ratio(mdl_A1_2, 2024, 1961, 97.6)
A1_3_97.6_1961 = prob_ratio(mdl_A1_3, 2024, 1961, 97.6)

A2_1_97.6_1874 = prob_ratio(mdl_A2_1, 2024, 1874, 97.6)
A2_2_97.6_1874 = prob_ratio(mdl_A2_2, 2024, 1874, 97.6)
A2_3_97.6_1874 = prob_ratio(mdl_A2_3, 2024, 1874, 97.6)

A2_1_97.6_1961 = prob_ratio(mdl_A2_1, 2024, 1961, 97.6)
A2_2_97.6_1961 = prob_ratio(mdl_A2_2, 2024, 1961, 97.6)
A2_3_97.6_1961 = prob_ratio(mdl_A2_3, 2024, 1961, 97.6)


A1_1_144.6_1874 = prob_ratio(mdl_A1_1, 2024, 1874, 144.6)
A1_2_144.6_1874 = prob_ratio(mdl_A1_2, 2024, 1874, 144.6)
A1_3_144.6_1874 = prob_ratio(mdl_A1_3, 2024, 1874, 144.6)

A1_1_144.6_1961 = prob_ratio(mdl_A1_1, 2024, 1961, 144.6)
A1_2_144.6_1961 = prob_ratio(mdl_A1_2, 2024, 1961, 144.6)
A1_3_144.6_1961 = prob_ratio(mdl_A1_3, 2024, 1961, 144.6)

A2_1_144.6_1874 = prob_ratio(mdl_A2_1, 2024, 1874, 144.6)
A2_2_144.6_1874 = prob_ratio(mdl_A2_2, 2024, 1874, 144.6)
A2_3_144.6_1874 = prob_ratio(mdl_A2_3, 2024, 1874, 144.6)

A2_1_144.6_1961 = prob_ratio(mdl_A2_1, 2024, 1961, 144.6)
A2_2_144.6_1961 = prob_ratio(mdl_A2_2, 2024, 1961, 144.6)
A2_3_144.6_1961 = prob_ratio(mdl_A2_3, 2024, 1961, 144.6)


# Dataset B

B1_1_97.6_1920 = prob_ratio(mdl_B1_1, 2024, 1920, 97.6)
B1_2_97.6_1920 = prob_ratio(mdl_B1_2, 2024, 1920, 97.6)
B1_3_97.6_1920 = prob_ratio(mdl_B1_3, 2024, 1920, 97.6)

B1_1_97.6_1961 = prob_ratio(mdl_B1_1, 2024, 1961, 97.6)
B1_2_97.6_1961 = prob_ratio(mdl_B1_2, 2024, 1961, 97.6)
B1_3_97.6_1961 = prob_ratio(mdl_B1_3, 2024, 1961, 97.6)

B2_1_97.6_1920 = prob_ratio(mdl_B2_1, 2024, 1920, 97.6)
B2_2_97.6_1920 = prob_ratio(mdl_B2_2, 2024, 1920, 97.6)
B2_3_97.6_1920 = prob_ratio(mdl_B2_3, 2024, 1920, 97.6)

B2_1_97.6_1961 = prob_ratio(mdl_B2_1, 2024, 1961, 97.6)
B2_2_97.6_1961 = prob_ratio(mdl_B2_2, 2024, 1961, 97.6)
B2_3_97.6_1961 = prob_ratio(mdl_B2_3, 2024, 1961, 97.6)


B1_1_144.6_1920 = prob_ratio(mdl_B1_1, 2024, 1920, 144.6)
B1_2_144.6_1920 = prob_ratio(mdl_B1_2, 2024, 1920, 144.6)
B1_3_144.6_1920 = prob_ratio(mdl_B1_3, 2024, 1920, 144.6)

B1_1_144.6_1961 = prob_ratio(mdl_B1_1, 2024, 1961, 144.6)
B1_2_144.6_1961 = prob_ratio(mdl_B1_2, 2024, 1961, 144.6)
B1_3_144.6_1961 = prob_ratio(mdl_B1_3, 2024, 1961, 144.6)

B2_1_144.6_1920 = prob_ratio(mdl_B2_1, 2024, 1920, 144.6)
B2_2_144.6_1920 = prob_ratio(mdl_B2_2, 2024, 1920, 144.6)
B2_3_144.6_1920 = prob_ratio(mdl_B2_3, 2024, 1920, 144.6)

B2_1_144.6_1961 = prob_ratio(mdl_B2_1, 2024, 1961, 144.6)
B2_2_144.6_1961 = prob_ratio(mdl_B2_2, 2024, 1961, 144.6)
B2_3_144.6_1961 = prob_ratio(mdl_B2_3, 2024, 1961, 144.6)


# Dataset C

C1_1_97.6_1961 = prob_ratio(mdl_C1_1, 2024, 1961, 97.6)
C1_2_97.6_1961 = prob_ratio(mdl_C1_2, 2024, 1961, 97.6)
C1_3_97.6_1961 = prob_ratio(mdl_C1_3, 2024, 1961, 97.6)

C2_1_97.6_1961 = prob_ratio(mdl_C2_1, 2024, 1961, 97.6)
C2_2_97.6_1961 = prob_ratio(mdl_C2_2, 2024, 1961, 97.6)
C2_3_97.6_1961 = prob_ratio(mdl_C2_3, 2024, 1961, 97.6)

C1_1_144.6_1961 = prob_ratio(mdl_C1_1, 2024, 1961, 144.6)
C1_2_144.6_1961 = prob_ratio(mdl_C1_2, 2024, 1961, 144.6)
C1_3_144.6_1961 = prob_ratio(mdl_C1_3, 2024, 1961, 144.6)

C2_stat_144.6_1961 = prob_ratio(mdl_C2_stat, 2024, 1961, 144.6)
C2_1_144.6_1961 = prob_ratio(mdl_C2_1, 2024, 1961, 144.6)
C2_2_144.6_1961 = prob_ratio(mdl_C2_2, 2024, 1961, 144.6)
C2_3_144.6_1961 = prob_ratio(mdl_C2_3, 2024, 1961, 144.6)

# Dataset Nordby 
Nordby1_1_97.6_1874 = prob_ratio(mdl_Nordby1_1, 2024, 1874, 97.6)
Nordby1_2_97.6_1874 = prob_ratio(mdl_Nordby1_2, 2024, 1874, 97.6)
Nordby1_3_97.6_1874 = prob_ratio(mdl_Nordby1_3, 2024, 1874, 97.6)

Nordby1_1_97.6_1961 = prob_ratio(mdl_Nordby1_1, 2024, 1961, 97.6)
Nordby1_2_97.6_1961 = prob_ratio(mdl_Nordby1_2, 2024, 1961, 97.6)
Nordby1_3_97.6_1961 = prob_ratio(mdl_Nordby1_3, 2024, 1961, 97.6)

Nordby2_1_97.6_1874 = prob_ratio(mdl_Nordby2_1, 2024, 1874, 97.6)
Nordby2_2_97.6_1874 = prob_ratio(mdl_Nordby2_2, 2024, 1874, 97.6)
Nordby2_3_97.6_1874 = prob_ratio(mdl_Nordby2_3, 2024, 1874, 97.6)

Nordby2_1_97.6_1961 = prob_ratio(mdl_Nordby2_1, 2024, 1961, 97.6)
Nordby2_2_97.6_1961 = prob_ratio(mdl_Nordby2_2, 2024, 1961, 97.6)
Nordby2_3_97.6_1961 = prob_ratio(mdl_Nordby2_3, 2024, 1961, 97.6)


Nordby1_1_144.6_1874 = prob_ratio(mdl_Nordby1_1, 2024, 1874, 144.6)
Nordby1_2_144.6_1874 = prob_ratio(mdl_Nordby1_2, 2024, 1874, 144.6)
Nordby1_3_144.6_1874 = prob_ratio(mdl_Nordby1_3, 2024, 1874, 144.6)

Nordby1_1_144.6_1961 = prob_ratio(mdl_Nordby1_1, 2024, 1961, 144.6)
Nordby1_2_144.6_1961 = prob_ratio(mdl_Nordby1_2, 2024, 1961, 144.6)
Nordby1_3_144.6_1961 = prob_ratio(mdl_Nordby1_3, 2024, 1961, 144.6)

Nordby2_1_144.6_1874 = prob_ratio(mdl_Nordby2_1, 2024, 1874, 144.6)
Nordby2_2_144.6_1874 = prob_ratio(mdl_Nordby2_2, 2024, 1874, 144.6)
Nordby2_3_144.6_1874 = prob_ratio(mdl_Nordby2_3, 2024, 1874, 144.6)

Nordby2_1_144.6_1961 = prob_ratio(mdl_Nordby2_1, 2024, 1961, 144.6)
Nordby2_2_144.6_1961 = prob_ratio(mdl_Nordby2_2, 2024, 1961, 144.6)
Nordby2_3_144.6_1961 = prob_ratio(mdl_Nordby2_3, 2024, 1961, 144.6)

# %% [markdown]
# * Threshold 144.6, 2024 ej inkluderat

# %%
cat("Dataset A")
A2_1_144.6_1874
A2_1_144.6_1961
A2_2_144.6_1874
A2_2_144.6_1961
A2_3_144.6_1874
A2_3_144.6_1961

cat("--------------------------------------------------\nDataset B")
B2_1_144.6_1920
B2_1_144.6_1961
B2_2_144.6_1920
B2_2_144.6_1961
B2_3_144.6_1920
B2_3_144.6_1961

cat("--------------------------------------------------\nDataset C")
C2_1_144.6_1961
C2_2_144.6_1961
C2_3_144.6_1961

cat("--------------------------------------------------\nDataset Nordby")
Nordby2_1_144.6_1874
Nordby2_1_144.6_1961
Nordby2_2_144.6_1874
Nordby2_2_144.6_1961
Nordby2_3_144.6_1874
Nordby2_3_144.6_1961
# Out:
# Dataset A
# $type
# [1] "Dataset: df_A2, Threshold: 144.6, Year PR & I: 1874, 2024: No, Trend: mu, Kovariat: tid"
#
# $P0
# [1] 0.0016942
#
# $P1
# [1] 0.0018639
#
# $PR
# [1] 1.10017
#
# $delta_I
# [1] 1.8591
#
# [[6]]
# [1] NA
# $type
# [1] "Dataset: df_A2, Threshold: 144.6, Year PR & I: 1961, 2024: No, Trend: mu, Kovariat: tid"
#
# $P0
# [1] 0.0017903
#
# $P1
# [1] 0.0018639
#
# $PR
# [1] 1.04111
#
# $delta_I
# [1] 0.77249
#
# [[6]]
# [1] NA
# $type
# [1] "Dataset: df_A2, Threshold: 144.6, Year PR & I: 1874, 2024: No, Trend:  sigma, Kovariat: tid"
#
# $P0
# [1] 0.0025816
#
# $P1
# [1] 0.0012043
#
# $PR
# [1] 0.46648
#
# $delta_I
# [1] -13.84812
#
# [[6]]
# [1] NA
# $type
# [1] "Dataset: df_A2, Threshold: 144.6, Year PR & I: 1961, 2024: No, Trend:  sigma, Kovariat: tid"
#
# $P0
# [1] 0.0016692
#
# $P1
# [1] 0.0012043
#
# $PR
# [1] 0.72145
#
# $delta_I
# [1] -5.98483
#
# [[6]]
# [1] NA
# $type
# ...

# %% [markdown]
# * Threshold 144.6, 2024 inkluderat

# %%
cat("Dataset A")
A1_1_144.6_1874
A1_1_144.6_1961
A1_2_144.6_1874
A1_2_144.6_1961
A1_3_144.6_1874
A1_3_144.6_1961

cat("--------------------------------------------------\nDataset B")
B1_1_144.6_1920
B1_1_144.6_1961
B1_2_144.6_1920
B1_2_144.6_1961
B1_3_144.6_1920
B1_3_144.6_1961

cat("--------------------------------------------------\nDataset C")
C1_1_144.6_1961
C1_2_144.6_1961
C1_3_144.6_1961

cat("--------------------------------------------------\nDataset Nordby")
Nordby1_1_144.6_1874
Nordby1_1_144.6_1961
Nordby1_2_144.6_1874
Nordby1_2_144.6_1961
Nordby1_3_144.6_1874
Nordby1_3_144.6_1961
# Out:
# Dataset A
# $type
# [1] "Dataset: df_A1, Threshold: 144.6, Year PR & I: 1874, 2024: Yes, Trend: mu, Kovariat: tid"
#
# $P0
# [1] 0.0021398
#
# $P1
# [1] 0.0023573
#
# $PR
# [1] 1.10169
#
# $delta_I
# [1] 1.99265
#
# [[6]]
# [1] NA
# $type
# [1] "Dataset: df_A1, Threshold: 144.6, Year PR & I: 1961, 2024: Yes, Trend: mu, Kovariat: tid"
#
# $P0
# [1] 0.0022629
#
# $P1
# [1] 0.0023573
#
# $PR
# [1] 1.04173
#
# $delta_I
# [1] 0.82735
#
# [[6]]
# [1] NA
# $type
# [1] "Dataset: df_A1, Threshold: 144.6, Year PR & I: 1874, 2024: Yes, Trend:  sigma, Kovariat: tid"
#
# $P0
# [1] 0.0029482
#
# $P1
# [1] 0.0017774
#
# $PR
# [1] 0.6029
#
# $delta_I
# [1] -9.89581
#
# [[6]]
# [1] NA
# $type
# [1] "Dataset: df_A1, Threshold: 144.6, Year PR & I: 1961, 2024: Yes, Trend:  sigma, Kovariat: tid"
#
# $P0
# [1] 0.0022045
#
# $P1
# [1] 0.0017774
#
# $PR
# [1] 0.80628
#
# $delta_I
# [1] -4.23922
#
# [[6]]
# [1] NA
# $type
# ...

# %% [markdown]
# * Threshold 97.6, 2024 ej inkluderat

# %%
cat("Dataset A")
A2_1_97.6_1874
A2_1_97.6_1961
A2_2_97.6_1874
A2_2_97.6_1961
A2_3_97.6_1874
A2_3_97.6_1961

cat("--------------------------------------------------\nDataset B")
B2_1_97.6_1920
B2_1_97.6_1961
B2_2_97.6_1920
B2_2_97.6_1961
B2_3_97.6_1920
B2_3_97.6_1961

cat("--------------------------------------------------\nDataset C")
C2_1_97.6_1961
C2_2_97.6_1961
C2_3_97.6_1961

cat("--------------------------------------------------\nDataset Nordby")
Nordby2_1_97.6_1874
Nordby2_1_97.6_1961
Nordby2_2_97.6_1874
Nordby2_2_97.6_1961
Nordby2_3_97.6_1874
Nordby2_3_97.6_1961
# Out:
# Dataset A
# $type
# [1] "Dataset: df_A2, Threshold: 97.6, Year PR & I: 1874, 2024: No, Trend: mu, Kovariat: tid"
#
# $P0
# [1] 0.0124031
#
# $P1
# [1] 0.01419
#
# $PR
# [1] 1.14407
#
# $delta_I
# [1] 2.77925
#
# [[6]]
# [1] NA
# $type
# [1] "Dataset: df_A2, Threshold: 97.6, Year PR & I: 1961, 2024: No, Trend: mu, Kovariat: tid"
#
# $P0
# [1] 0.0134051
#
# $P1
# [1] 0.01419
#
# $PR
# [1] 1.05855
#
# $delta_I
# [1] 1.14877
#
# [[6]]
# [1] NA
# $type
# [1] "Dataset: df_A2, Threshold: 97.6, Year PR & I: 1874, 2024: No, Trend:  sigma, Kovariat: tid"
#
# $P0
# [1] 0.017833
#
# $P1
# [1] 0.0098021
#
# $PR
# [1] 0.54966
#
# $delta_I
# [1] -11.71562
#
# [[6]]
# [1] NA
# $type
# [1] "Dataset: df_A2, Threshold: 97.6, Year PR & I: 1961, 2024: No, Trend:  sigma, Kovariat: tid"
#
# $P0
# [1] 0.0126937
#
# $P1
# [1] 0.0098021
#
# $PR
# [1] 0.7722
#
# $delta_I
# [1] -4.99304
#
# [[6]]
# [1] NA
# $type
# ...

# %% [markdown]
# * Threshold 97.6, 2024 inkluderat

# %%
cat("Dataset A")
A1_1_97.6_1874
A1_1_97.6_1961
A1_2_97.6_1874
A1_2_97.6_1961
A1_3_97.6_1874
A1_3_97.6_1961

cat("--------------------------------------------------\nDataset B")
B1_1_97.6_1920
B1_1_97.6_1961
B1_2_97.6_1920
B1_2_97.6_1961
B1_3_97.6_1920
B1_3_97.6_1961

cat("--------------------------------------------------\nDataset C")
C1_1_97.6_1961
C1_2_97.6_1961
C1_3_97.6_1961

cat("--------------------------------------------------\nDataset Nordby")
Nordby1_1_97.6_1874
Nordby1_1_97.6_1961
Nordby1_2_97.6_1874
Nordby1_2_97.6_1961
Nordby1_3_97.6_1874
Nordby1_3_97.6_1961
# Out:
# Dataset A
# $type
# [1] "Dataset: df_A1, Threshold: 97.6, Year PR & I: 1874, 2024: Yes, Trend: mu, Kovariat: tid"
#
# $P0
# [1] 0.0141918
#
# $P1
# [1] 0.0162854
#
# $PR
# [1] 1.14752
#
# $delta_I
# [1] 2.98083
#
# [[6]]
# [1] NA
# $type
# [1] "Dataset: df_A1, Threshold: 97.6, Year PR & I: 1961, 2024: Yes, Trend: mu, Kovariat: tid"
#
# $P0
# [1] 0.0153645
#
# $P1
# [1] 0.0162854
#
# $PR
# [1] 1.05994
#
# $delta_I
# [1] 1.23067
#
# [[6]]
# [1] NA
# $type
# [1] "Dataset: df_A1, Threshold: 97.6, Year PR & I: 1874, 2024: Yes, Trend:  sigma, Kovariat: tid"
#
# $P0
# [1] 0.018822
#
# $P1
# [1] 0.0126124
#
# $PR
# [1] 0.67009
#
# $delta_I
# [1] -8.31024
#
# [[6]]
# [1] NA
# $type
# [1] "Dataset: df_A1, Threshold: 97.6, Year PR & I: 1961, 2024: Yes, Trend:  sigma, Kovariat: tid"
#
# $P0
# [1] 0.0149708
#
# $P1
# [1] 0.0126124
#
# $PR
# [1] 0.84246
#
# $delta_I
# [1] -3.52453
#
# [[6]]
# [1] NA
# $type
# ...
