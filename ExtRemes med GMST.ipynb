# %%
library(extRemes)

# %% [markdown]
# * Ladda in datamängderna

# %%
# Ladda in alla dataset och lägga in gmst i dem, 
# göra "under-sets" utan inkludering av 2024

gmst <- read.csv("/Users/joel/Livet/Globala System/År 3/LP 3/Kandidatarbete/Newell-Matthew-CCDetectonAttribution_Esbjerg-ac778b5/files/Rx1day-files/annual_sampling/observations/gmst/GMST_anomalies.csv", col.names = c("year", "GMST"), sep = ";", header = TRUE)
setwd("/Users/joel/Livet/Globala System/År 3/LP 3/Kandidatarbete/Kandidatarbete kod")

df_C <- read.csv("Färdig_data_fler_punkter.csv") # 1961 data
df_B <- read.csv("data_1920_2025.csv") # 1920 data
df_A <- read.csv("Block_maxima_1874_2025.csv") # 1874 data
df_Nordby <- read.csv("Nordby_1874_2025_max.csv") # Nordby data

df_C1 <- merge(df_C, gmst, by = "year")
df_C2 <- df_C1[df_C1$year <= 2023, ] 

df_B1 <- merge(df_B, gmst, by = "year")
df_B2 <- df_B1[df_B1$year <= 2023, ] 

df_A1 <- merge(df_A, gmst, by = "year")
df_A2 <- df_A1[df_A1$year <= 2023, ]

df_A2_1920 <- df_A2[df_A2$year >= 1920, ] 
df_A2_1961 <- df_A2[df_A2$year >= 1961, ] 

df_Nordby<- df_Nordby[, -1]
df_Nordby1 <- merge(df_Nordby, gmst, by = "year")
df_Nordby2 <- df_Nordby1[df_Nordby1$year <= 2023, ]

# %% [markdown]
# * Stationära modeller:

# %%
mdl_A1_stat <- fevd(rain, 
                 data = df_A1, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_stat <- fevd(rain, 
                 data = df_A2, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )


mdl_A2_1874_stat <- fevd(rain, 
                 data = df_A2_1874, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_1961_stat <- fevd(rain, 
                 data = df_A2_1961, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_B1_stat <- fevd(rain, 
                 data = df_B1, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_B2_stat <- fevd(rain, 
                 data = df_B2, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_C1_stat <- fevd(rain, 
                 data = df_C1, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_C2_stat <- fevd(rain, 
                 data = df_C2, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_Nordby1_stat <- fevd(rain, 
                 data = df_Nordby1, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_Nordby2_stat <- fevd(rain, 
                 data = df_Nordby2, 
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# %% [markdown]
# * Linjära trender i mu

# %%
mdl_A1_1 <- fevd(rain, 
                 data = df_A1, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_1 <- fevd(rain, 
                 data = df_A2, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_1920_1 <- fevd(rain, 
                 data = df_A2_1920, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_1961_1 <- fevd(rain, 
                 data = df_A2_1961, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# Data B

mdl_B1_1 <- fevd(rain, 
                 data = df_B1, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_B2_1 <- fevd(rain, 
                 data = df_B2, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# Data C


mdl_C1_1 <- fevd(rain, 
                 data = df_C1, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_C2_1 <- fevd(rain, 
                 data = df_C2, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_Nordby1_1 <- fevd(rain, 
                 data = df_Nordby1, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_Nordby2_1 <- fevd(rain, 
                 data = df_Nordby2, 
                 location.fun = ~GMST,
                 use.phi = TRUE,  
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# %% [markdown]
# * Exponentiella trender i sigma

# %%
mdl_A1_2 <- fevd(rain, 
                 data = df_A1, 
                 scale.fun = ~GMST,
                 use.phi = TRUE,
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_2 <- fevd(rain, 
                 data = df_A2, 
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_1920_2 <- fevd(rain, 
                 data = df_A2_1920, 
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_1961_2 <- fevd(rain, 
                 data = df_A2_1961, 
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )


# Data B

mdl_B1_2 <- fevd(rain, 
                 data = df_B1, 
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_B2_2 <- fevd(rain, 
                 data = df_B2, 
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# Data C


mdl_C1_2 <- fevd(rain, 
                 data = df_C1, 
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_C2_2 <- fevd(rain, 
                 data = df_C2, 
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )


mdl_Nordby1_2 <- fevd(rain, 
                 data = df_Nordby1, 
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_Nordby2_2 <- fevd(rain, 
                 data = df_Nordby2, 
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# %% [markdown]
# * Linjära trender i mu och exponentiella trender i sigma

# %%
mdl_A1_3 <- fevd(rain, 
                 data = df_A1, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE,
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_3 <- fevd(rain, 
                 data = df_A2, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_1920_3 <- fevd(rain, 
                 data = df_A2_1920, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_A2_1961_3 <- fevd(rain, 
                 data = df_A2_1961, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )


# Data B

mdl_B1_3 <- fevd(rain, 
                 data = df_B1, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_B2_3 <- fevd(rain, 
                 data = df_B2, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# Data C


mdl_C1_3 <- fevd(rain, 
                 data = df_C1, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_C2_3 <- fevd(rain, 
                 data = df_C2, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_Nordby1_3 <- fevd(rain, 
                 data = df_Nordby1, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

mdl_Nordby2_3 <- fevd(rain, 
                 data = df_Nordby2, 
                 location.fun = ~GMST,
                 scale.fun = ~GMST,
                 use.phi = TRUE, 
                 type = "GEV",
                 method = "MLE",
                 units = "mm",
                )

# %% [markdown]
# * Beräknar p-värden för alla modeller, jämfört med sina respektive stationära

# %%
cat("\nP-värden 1, 2 och 3 motsvarar trendmodellerna.\n")

cat("\nP-värde dataset A med 2024:")
lr.test(mdl_A1_stat, mdl_A1_1)$p.value
lr.test(mdl_A1_stat, mdl_A1_2)$p.value
lr.test(mdl_A1_stat, mdl_A1_3)$p.value

cat("\nP-värde dataset A utan 2024:")
lr.test(mdl_A2_stat, mdl_A2_1)$p.value
lr.test(mdl_A2_stat, mdl_A2_2)$p.value
lr.test(mdl_A2_stat, mdl_A2_3)$p.value

cat("\nP-värde dataset B med 2024:")
lr.test(mdl_B1_stat, mdl_B1_1)$p.value
lr.test(mdl_B1_stat, mdl_B1_2)$p.value
lr.test(mdl_B1_stat, mdl_B1_3)$p.value

cat("\nP-värde dataset B utan 2024:")
lr.test(mdl_B2_stat, mdl_B2_1)$p.value
lr.test(mdl_B2_stat, mdl_B2_2)$p.value
lr.test(mdl_B2_stat, mdl_B2_3)$p.value

cat("\nP-värde dataset C med 2024:")
lr.test(mdl_C1_stat, mdl_C1_1)$p.value
lr.test(mdl_C1_stat, mdl_C1_2)$p.value
lr.test(mdl_C1_stat, mdl_C1_3)$p.value

cat("\nP-värde dataset C utan 2024:")
lr.test(mdl_C2_stat, mdl_C2_1)$p.value
lr.test(mdl_C2_stat, mdl_C2_2)$p.value
lr.test(mdl_C2_stat, mdl_C2_3)$p.value

cat("\nP-värde dataset Nordby med 2024:")
lr.test(mdl_Nordby1_stat, mdl_Nordby1_1)$p.value
lr.test(mdl_Nordby1_stat, mdl_Nordby1_2)$p.value
lr.test(mdl_Nordby1_stat, mdl_Nordby1_3)$p.value

cat("\nP-värde dataset Nordby utan 2024:")
lr.test(mdl_Nordby2_stat, mdl_Nordby2_1)$p.value
lr.test(mdl_Nordby2_stat, mdl_Nordby2_2)$p.value
lr.test(mdl_Nordby2_stat, mdl_Nordby2_3)$p.value

cat("\nP-värde dataset A modell trend mu och sigma, dataset start 1920/1961:")
lr.test(mdl_A2_1874_stat, mdl_A2_1874_3)$p.value
lr.test(mdl_A2_1961_stat, mdl_A2_1961_3)$p.value
# Out:
# P-värden 1, 2 och 3 motsvarar trendmodellerna.
#
# P-värde dataset A med 2024:
# Likelihood-ratio
#        0.2199344
# Likelihood-ratio
#         0.824534
# Likelihood-ratio
#        0.2974211
# P-värde dataset A utan 2024:
# Likelihood-ratio
#         0.261759
# Likelihood-ratio
#         0.846055
# Likelihood-ratio
#        0.4840769
# P-värde dataset B med 2024:
# Likelihood-ratio
#        0.1461821
# Likelihood-ratio
#        0.3774859
# Likelihood-ratio
#        0.3271658
# P-värde dataset B utan 2024:
# Likelihood-ratio
#         0.179897
# Likelihood-ratio
#        0.1971085
# Likelihood-ratio
#        0.2894009
# P-värde dataset C med 2024:
# Likelihood-ratio
#         0.109682
# Likelihood-ratio
#        0.9921712
# Likelihood-ratio
#        0.2136563
# P-värde dataset C utan 2024:
# Likelihood-ratio
#        0.1366698
# Likelihood-ratio
#        0.7283578
# Likelihood-ratio
#        0.3139468
# P-värde dataset Nordby med 2024:
# Likelihood-ratio
#        0.1061245
# ...

# %% [markdown]
# * Funktion för beräkning av PR och delta_I, som kan ge alla under-parametrar också om extra = TRUE

# %%
prob_ratio <- function(mdl, year_f, year_cf, x_val, COV, extra = FALSE){

    # ladda in datan från modellen GEV-modellen
    df = mdl$cov.data

    # Hitta GMST för year_f
    cov_f  <- COV$GMST[COV$year == year_f]
    # Hitta GMST för year_cf
    cov_cf <- COV$GMST[COV$year == year_cf]

    # Kolla om 2024 är inkluderat i dataanpassningen
    if (2024 %in% mdl$cov.data$year) {
        inc_2024 <- "Yes"   
    }
    else {
        inc_2024 <- "No"
    }

    # Ta fram parametervärden för år f och cf, samt underliggande parametervärden

    par <- mdl$results$par
    trend = ""
    
    if("mu1" %in% names(par)) {
        # finns mu1 så har vi trend i mu
        mu_f  <- par["mu0"] + par["mu1"] * cov_f
        mu_cf <- par["mu0"] + par["mu1"] * cov_cf

        mu0 = par["mu0"]
        mu1 = par["mu1"]

        trend <- paste0(trend, "mu")
        
    } else {
        # Stationär mu
        mu_f = par["location"]
        mu_cf = par["location"]

        mu0 = par["location"]
        mu1 = NA
    }

    # Kolla om det finns trend i sigma
    if("phi1" %in% names(par)) {
        # Finns phi1 så har vi log-linjär trend i sigma
        sigma_f  <- exp(par["phi0"] + par["phi1"] * cov_f)
        sigma_cf <- exp(par["phi0"] + par["phi1"] * cov_cf)
        
        phi0 = par["phi0"]
        phi1 = par["phi1"]

        trend <- paste(trend, "sigma")
        
    } else {
        # Stationär sigma
        sigma_f  <- exp(par["log.scale"])
        sigma_cf <- exp(par["log.scale"])

        phi0 = par["log.scale"]
        phi1 = NA
    }

    # beräknar överskridande sannolikheter för regnet med de givna parametervärdena
    prob_f <- 1 - pevd(x_val, 
                        loc = mu_f, 
                        scale = sigma_f, 
                        shape = par["shape"], 
                        type = "GEV")
    
    
    prob_cf <- 1 - pevd(x_val, 
                        loc = mu_cf, 
                        scale = sigma_cf, 
                        shape = par["shape"], 
                        type = "GEV")

    # Beräknar intensitet på ett regn med samma sannolikhet som 144.6 i 2024 för vårat year_cf
    I0 <- unname(qevd(1 - prob_f,
               loc   = mu_cf,
               scale = sigma_cf,
               shape = par["shape"],
               type  = "GEV"))
    
    # Relativ intensitetsförändring
    delta_I <- ((x_val - I0)/I0 ) * 100

    # Probability ratio
    P0 = prob_cf
    P1 = prob_f
    
    PR = P1/P0

    # Gör en lista med alla parametrar för modellen
    sigma0 = sprintf("Sigma0: %s",exp(unname(phi0)))
    shape = par["shape"]
    pars = NA
    if (extra==TRUE){
        pars = list(mu0, mu1, sigma0, phi0, phi1, shape
            )
        }
    
    resultat = list("type" = sprintf("Dataset: %s, Threshold: %s, Year PR & I: %s, 2024: %s, Trend: %s, Kovariat: %s", mdl$data[2], x_val , year_cf, inc_2024, trend, "GMST"),
    "P1" = round(P1, 8), "P0" = round(P0, 8), "PR" = round(PR, 5), "delta_I" = round(delta_I, 5), "Parametrar" = pars
    )

    return(resultat)  
    }

# %%
A1_1_97.6_1874 = prob_ratio(mdl_A1_1, 2024, 1874, 97.6, gmst)
A1_2_97.6_1874 = prob_ratio(mdl_A1_2, 2024, 1874, 97.6, gmst)
A1_3_97.6_1874 = prob_ratio(mdl_A1_3, 2024, 1874, 97.6, gmst)

A1_1_97.6_1961 = prob_ratio(mdl_A1_1, 2024, 1961, 97.6, gmst)
A1_2_97.6_1961 = prob_ratio(mdl_A1_2, 2024, 1961, 97.6, gmst)
A1_3_97.6_1961 = prob_ratio(mdl_A1_3, 2024, 1961, 97.6, gmst)

A2_1_97.6_1874 = prob_ratio(mdl_A2_1, 2024, 1874, 97.6, gmst)
A2_2_97.6_1874 = prob_ratio(mdl_A2_2, 2024, 1874, 97.6, gmst)
A2_3_97.6_1874 = prob_ratio(mdl_A2_3, 2024, 1874, 97.6, gmst)

A2_1_97.6_1961 = prob_ratio(mdl_A2_1, 2024, 1961, 97.6, gmst)
A2_2_97.6_1961 = prob_ratio(mdl_A2_2, 2024, 1961, 97.6, gmst)
A2_3_97.6_1961 = prob_ratio(mdl_A2_3, 2024, 1961, 97.6, gmst)


A1_1_144.6_1874 = prob_ratio(mdl_A1_1, 2024, 1874, 144.6, gmst)
A1_2_144.6_1874 = prob_ratio(mdl_A1_2, 2024, 1874, 144.6, gmst)
A1_3_144.6_1874 = prob_ratio(mdl_A1_3, 2024, 1874, 144.6, gmst)

A1_1_144.6_1961 = prob_ratio(mdl_A1_1, 2024, 1961, 144.6, gmst)
A1_2_144.6_1961 = prob_ratio(mdl_A1_2, 2024, 1961, 144.6, gmst)
A1_3_144.6_1961 = prob_ratio(mdl_A1_3, 2024, 1961, 144.6, gmst)

A2_1_144.6_1874 = prob_ratio(mdl_A2_1, 2024, 1874, 144.6, gmst)
A2_2_144.6_1874 = prob_ratio(mdl_A2_2, 2024, 1874, 144.6, gmst)
A2_3_144.6_1874 = prob_ratio(mdl_A2_3, 2024, 1874, 144.6, gmst)
A2_3_1920_144.6_1920 = prob_ratio(mdl_A2_1920_3, 2024, 1920, 144.6, gmst)

A2_1_144.6_1961 = prob_ratio(mdl_A2_1, 2024, 1961, 144.6, gmst)
A2_2_144.6_1961 = prob_ratio(mdl_A2_2, 2024, 1961, 144.6, gmst)
A2_3_144.6_1961 = prob_ratio(mdl_A2_1961_3, 2024, 1961, 144.6, gmst)
A2_3_1920_144.6_1961 = prob_ratio(mdl_A2_1920_3, 2024, 1961, 144.6, gmst)
A2_3_1961_144.6_1961 = prob_ratio(mdl_A2_1961_3, 2024, 1961, 144.6, gmst)


# Dataset B

B1_1_97.6_1920 = prob_ratio(mdl_B1_1, 2024, 1920, 97.6, gmst)
B1_2_97.6_1920 = prob_ratio(mdl_B1_2, 2024, 1920, 97.6, gmst)
B1_3_97.6_1920 = prob_ratio(mdl_B1_3, 2024, 1920, 97.6, gmst)

B1_1_97.6_1961 = prob_ratio(mdl_B1_1, 2024, 1961, 97.6, gmst)
B1_2_97.6_1961 = prob_ratio(mdl_B1_2, 2024, 1961, 97.6, gmst)
B1_3_97.6_1961 = prob_ratio(mdl_B1_3, 2024, 1961, 97.6, gmst)

B2_1_97.6_1920 = prob_ratio(mdl_B2_1, 2024, 1920, 97.6, gmst)
B2_2_97.6_1920 = prob_ratio(mdl_B2_2, 2024, 1920, 97.6, gmst)
B2_3_97.6_1920 = prob_ratio(mdl_B2_3, 2024, 1920, 97.6, gmst)

B2_1_97.6_1961 = prob_ratio(mdl_B2_1, 2024, 1961, 97.6, gmst)
B2_2_97.6_1961 = prob_ratio(mdl_B2_2, 2024, 1961, 97.6, gmst)
B2_3_97.6_1961 = prob_ratio(mdl_B2_3, 2024, 1961, 97.6, gmst)


B1_1_144.6_1920 = prob_ratio(mdl_B1_1, 2024, 1920, 144.6, gmst)
B1_2_144.6_1920 = prob_ratio(mdl_B1_2, 2024, 1920, 144.6, gmst)
B1_3_144.6_1920 = prob_ratio(mdl_B1_3, 2024, 1920, 144.6, gmst)

B1_1_144.6_1961 = prob_ratio(mdl_B1_1, 2024, 1961, 144.6, gmst)
B1_2_144.6_1961 = prob_ratio(mdl_B1_2, 2024, 1961, 144.6, gmst)
B1_3_144.6_1961 = prob_ratio(mdl_B1_3, 2024, 1961, 144.6, gmst)

B2_1_144.6_1920 = prob_ratio(mdl_B2_1, 2024, 1920, 144.6, gmst)
B2_2_144.6_1920 = prob_ratio(mdl_B2_2, 2024, 1920, 144.6, gmst)
B2_3_144.6_1920 = prob_ratio(mdl_B2_3, 2024, 1920, 144.6, gmst)

B2_1_144.6_1961 = prob_ratio(mdl_B2_1, 2024, 1961, 144.6, gmst)
B2_2_144.6_1961 = prob_ratio(mdl_B2_2, 2024, 1961, 144.6, gmst)
B2_3_144.6_1961 = prob_ratio(mdl_B2_3, 2024, 1961, 144.6, gmst)


# Dataset C

C1_1_97.6_1961 = prob_ratio(mdl_C1_1, 2024, 1961, 97.6, gmst)
C1_2_97.6_1961 = prob_ratio(mdl_C1_2, 2024, 1961, 97.6, gmst)
C1_3_97.6_1961 = prob_ratio(mdl_C1_3, 2024, 1961, 97.6, gmst)

C2_1_97.6_1961 = prob_ratio(mdl_C2_1, 2024, 1961, 97.6, gmst)
C2_2_97.6_1961 = prob_ratio(mdl_C2_2, 2024, 1961, 97.6, gmst)
C2_3_97.6_1961 = prob_ratio(mdl_C2_3, 2024, 1961, 97.6, gmst)

C1_1_144.6_1961 = prob_ratio(mdl_C1_1, 2024, 1961, 144.6, gmst)
C1_2_144.6_1961 = prob_ratio(mdl_C1_2, 2024, 1961, 144.6, gmst)
C1_3_144.6_1961 = prob_ratio(mdl_C1_3, 2024, 1961, 144.6, gmst)

C2_stat_144.6_1961 = prob_ratio(mdl_C2_stat, 2024, 1961, 144.6, gmst)
C2_1_144.6_1961 = prob_ratio(mdl_C2_1, 2024, 1961, 144.6, gmst)
C2_2_144.6_1961 = prob_ratio(mdl_C2_2, 2024, 1961, 144.6, gmst)
C2_3_144.6_1961 = prob_ratio(mdl_C2_3, 2024, 1961, 144.6, gmst)

# Dataset Nordby 
Nordby1_1_97.6_1874 = prob_ratio(mdl_Nordby1_1, 2024, 1874, 97.6, gmst)
Nordby1_2_97.6_1874 = prob_ratio(mdl_Nordby1_2, 2024, 1874, 97.6, gmst)
Nordby1_3_97.6_1874 = prob_ratio(mdl_Nordby1_3, 2024, 1874, 97.6, gmst)

Nordby1_1_97.6_1961 = prob_ratio(mdl_Nordby1_1, 2024, 1961, 97.6, gmst)
Nordby1_2_97.6_1961 = prob_ratio(mdl_Nordby1_2, 2024, 1961, 97.6, gmst)
Nordby1_3_97.6_1961 = prob_ratio(mdl_Nordby1_3, 2024, 1961, 97.6, gmst)

Nordby2_1_97.6_1874 = prob_ratio(mdl_Nordby2_1, 2024, 1874, 97.6, gmst)
Nordby2_2_97.6_1874 = prob_ratio(mdl_Nordby2_2, 2024, 1874, 97.6, gmst)
Nordby2_3_97.6_1874 = prob_ratio(mdl_Nordby2_3, 2024, 1874, 97.6, gmst)

Nordby2_1_97.6_1961 = prob_ratio(mdl_Nordby2_1, 2024, 1961, 97.6, gmst)
Nordby2_2_97.6_1961 = prob_ratio(mdl_Nordby2_2, 2024, 1961, 97.6, gmst)
Nordby2_3_97.6_1961 = prob_ratio(mdl_Nordby2_3, 2024, 1961, 97.6, gmst)


Nordby1_1_144.6_1874 = prob_ratio(mdl_Nordby1_1, 2024, 1874, 144.6, gmst)
Nordby1_2_144.6_1874 = prob_ratio(mdl_Nordby1_2, 2024, 1874, 144.6, gmst)
Nordby1_3_144.6_1874 = prob_ratio(mdl_Nordby1_3, 2024, 1874, 144.6, gmst)

Nordby1_1_144.6_1961 = prob_ratio(mdl_Nordby1_1, 2024, 1961, 144.6, gmst)
Nordby1_2_144.6_1961 = prob_ratio(mdl_Nordby1_2, 2024, 1961, 144.6, gmst)
Nordby1_3_144.6_1961 = prob_ratio(mdl_Nordby1_3, 2024, 1961, 144.6, gmst)

Nordby2_1_144.6_1874 = prob_ratio(mdl_Nordby2_1, 2024, 1874, 144.6, gmst)
Nordby2_2_144.6_1874 = prob_ratio(mdl_Nordby2_2, 2024, 1874, 144.6, gmst)
Nordby2_3_144.6_1874 = prob_ratio(mdl_Nordby2_3, 2024, 1874, 144.6, gmst)

Nordby2_1_144.6_1961 = prob_ratio(mdl_Nordby2_1, 2024, 1961, 144.6, gmst)
Nordby2_2_144.6_1961 = prob_ratio(mdl_Nordby2_2, 2024, 1961, 144.6, gmst)
Nordby2_3_144.6_1961 = prob_ratio(mdl_Nordby2_3, 2024, 1961, 144.6, gmst)

# %%
options(scipen = 999)

# %% [markdown]
# * Kör prob_ratio med alla de datamängder, startår samt intensiteter vi är intresserade av

# %% [markdown]
# * Threshold 144.6, 2024 ej inkluderat

# %%
cat("Dataset A")
A2_1_144.6_1874
A2_1_144.6_1961
A2_2_144.6_1874
A2_2_144.6_1961
A2_3_144.6_1874
A2_3_144.6_1961



cat("--------------------------------------------------\nDataset B")
B2_1_144.6_1920
B2_1_144.6_1961
B2_2_144.6_1920
B2_2_144.6_1961
B2_3_144.6_1920
B2_3_144.6_1961

cat("--------------------------------------------------\nDataset C")
C2_1_144.6_1961
C2_2_144.6_1961
C2_3_144.6_1961

cat("--------------------------------------------------\nDataset Nordby")
Nordby2_1_144.6_1874
Nordby2_1_144.6_1961
Nordby2_2_144.6_1874
Nordby2_2_144.6_1961
Nordby2_3_144.6_1874
Nordby2_3_144.6_1961
# Out:
# Dataset A
# $type
# [1] "Dataset: df_A2, Threshold: 144.6, Year PR & I: 1874, 2024: No, Trend: mu, Kovariat: GMST"
#
# $P1
# [1] 0.0018209
#
# $P0
# [1] 0.00164252
#
# $PR
# [1] 1.1086
#
# $delta_I
# [1] 1.9673
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A2, Threshold: 144.6, Year PR & I: 1961, 2024: No, Trend: mu, Kovariat: GMST"
#
# $P1
# [1] 0.0018209
#
# $P0
# [1] 0.00167995
#
# $PR
# [1] 1.0839
#
# $delta_I
# [1] 1.52784
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A2, Threshold: 144.6, Year PR & I: 1874, 2024: No, Trend:  sigma, Kovariat: GMST"
#
# $P1
# [1] 0.00150877
#
# $P0
# [1] 0.00180426
#
# $PR
# [1] 0.83622
#
# $delta_I
# [1] -3.32924
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A2, Threshold: 144.6, Year PR & I: 1961, 2024: No, Trend:  sigma, Kovariat: GMST"
#
# $P1
# [1] 0.00150877
#
# $P0
# [1] 0.00173505
#
# $PR
# [1] 0.86958
#
# $delta_I
# [1] -2.60299
#
# $Parametrar
# [1] NA
# $type
# ...

# %% [markdown]
# * Threshold 144.6, 2024 inkluderat

# %%
cat("Dataset A")
A1_1_144.6_1874
A1_1_144.6_1961
A1_2_144.6_1874
A1_2_144.6_1961
A1_3_144.6_1874
A1_3_144.6_1961

cat("--------------------------------------------------\nDataset B")
B1_1_144.6_1920
B1_1_144.6_1961
B1_2_144.6_1920
B1_2_144.6_1961
B1_3_144.6_1920
B1_3_144.6_1961

cat("--------------------------------------------------\nDataset C")
C1_1_144.6_1961
C1_2_144.6_1961
C1_3_144.6_1961

cat("--------------------------------------------------\nDataset Nordby")
Nordby1_1_144.6_1874
Nordby1_1_144.6_1961
Nordby1_2_144.6_1874
Nordby1_2_144.6_1961
Nordby1_3_144.6_1874
Nordby1_3_144.6_1961
# Out:
# Dataset A
# $type
# [1] "Dataset: df_A1, Threshold: 144.6, Year PR & I: 1874, 2024: Yes, Trend: mu, Kovariat: GMST"
#
# $P1
# [1] 0.0022946
#
# $P0
# [1] 0.0020619
#
# $PR
# [1] 1.11286
#
# $delta_I
# [1] 2.15077
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A1, Threshold: 144.6, Year PR & I: 1961, 2024: Yes, Trend: mu, Kovariat: GMST"
#
# $P1
# [1] 0.0022946
#
# $P0
# [1] 0.00211061
#
# $PR
# [1] 1.08717
#
# $delta_I
# [1] 1.66965
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A1, Threshold: 144.6, Year PR & I: 1874, 2024: Yes, Trend:  sigma, Kovariat: GMST"
#
# $P1
# [1] 0.00245293
#
# $P0
# [1] 0.00201652
#
# $PR
# [1] 1.21642
#
# $delta_I
# [1] 3.93374
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A1, Threshold: 144.6, Year PR & I: 1961, 2024: Yes, Trend:  sigma, Kovariat: GMST"
#
# $P1
# [1] 0.00245293
#
# $P0
# [1] 0.00210597
#
# $PR
# [1] 1.16475
#
# $delta_I
# [1] 3.06006
#
# $Parametrar
# [1] NA
# $type
# ...

# %% [markdown]
# * Threshold 97.6, 2024 ej inkluderat

# %%
cat("Dataset A")
A2_1_97.6_1874
A2_1_97.6_1961
A2_2_97.6_1874
A2_2_97.6_1961
A2_3_97.6_1874
A2_3_97.6_1961

cat("--------------------------------------------------\nDataset B")
B2_1_97.6_1920
B2_1_97.6_1961
B2_2_97.6_1920
B2_2_97.6_1961
B2_3_97.6_1920
B2_3_97.6_1961

cat("--------------------------------------------------\nDataset C")
C2_1_97.6_1961
C2_2_97.6_1961
C2_3_97.6_1961

cat("--------------------------------------------------\nDataset Nordby")
Nordby2_1_97.6_1874
Nordby2_1_97.6_1961
Nordby2_2_97.6_1874
Nordby2_2_97.6_1961
Nordby2_3_97.6_1874
Nordby2_3_97.6_1961
# Out:
# Dataset A
# $type
# [1] "Dataset: df_A2, Threshold: 97.6, Year PR & I: 1874, 2024: No, Trend: mu, Kovariat: GMST"
#
# $P1
# [1] 0.01447243
#
# $P0
# [1] 0.01251835
#
# $PR
# [1] 1.1561
#
# $delta_I
# [1] 2.94255
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A2, Threshold: 97.6, Year PR & I: 1961, 2024: No, Trend: mu, Kovariat: GMST"
#
# $P1
# [1] 0.01447243
#
# $P0
# [1] 0.01292052
#
# $PR
# [1] 1.12011
#
# $delta_I
# [1] 2.28036
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A2, Threshold: 97.6, Year PR & I: 1874, 2024: No, Trend:  sigma, Kovariat: GMST"
#
# $P1
# [1] 0.0118374
#
# $P0
# [1] 0.01362028
#
# $PR
# [1] 0.8691
#
# $delta_I
# [1] -2.76524
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A2, Threshold: 97.6, Year PR & I: 1961, 2024: No, Trend:  sigma, Kovariat: GMST"
#
# $P1
# [1] 0.0118374
#
# $P0
# [1] 0.01320989
#
# $PR
# [1] 0.8961
#
# $delta_I
# [1] -2.15928
#
# $Parametrar
# [1] NA
# $type
# ...

# %% [markdown]
# * Threshold 97.6, 2024 inkluderat

# %%
cat("Dataset A")
A1_1_97.6_1874
A1_1_97.6_1961
A1_2_97.6_1874
A1_2_97.6_1961
A1_3_97.6_1874
A1_3_97.6_1961

cat("\n--------------------------------------------------\nDataset B\n")
B1_1_97.6_1920
B1_1_97.6_1961
B1_2_97.6_1920
B1_2_97.6_1961
B1_3_97.6_1920
B1_3_97.6_1961

cat("\n--------------------------------------------------\nDataset C\n")
C1_1_97.6_1961
C1_2_97.6_1961
C1_3_97.6_1961

cat("\n--------------------------------------------------\nDataset Nordby\n")
Nordby1_1_97.6_1874
Nordby1_1_97.6_1961
Nordby1_2_97.6_1874
Nordby1_2_97.6_1961
Nordby1_3_97.6_1874
Nordby1_3_97.6_1961
# Out:
# Dataset A
# $type
# [1] "Dataset: df_A1, Threshold: 97.6, Year PR & I: 1874, 2024: Yes, Trend: mu, Kovariat: GMST"
#
# $P1
# [1] 0.01661505
#
# $P0
# [1] 0.01427783
#
# $PR
# [1] 1.1637
#
# $delta_I
# [1] 3.21984
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A1, Threshold: 97.6, Year PR & I: 1961, 2024: Yes, Trend: mu, Kovariat: GMST"
#
# $P1
# [1] 0.01661505
#
# $P0
# [1] 0.01475704
#
# $PR
# [1] 1.12591
#
# $delta_I
# [1] 2.49374
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A1, Threshold: 97.6, Year PR & I: 1874, 2024: Yes, Trend:  sigma, Kovariat: GMST"
#
# $P1
# [1] 0.01667119
#
# $P0
# [1] 0.01429363
#
# $PR
# [1] 1.16634
#
# $delta_I
# [1] 3.22573
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A1, Threshold: 97.6, Year PR & I: 1961, 2024: Yes, Trend:  sigma, Kovariat: GMST"
#
# $P1
# [1] 0.01667119
#
# $P0
# [1] 0.01479094
#
# $PR
# [1] 1.12712
#
# $delta_I
# [1] 2.5131
#
# $Parametrar
# [1] NA
# $type
# ...

# %% [markdown]
# * Längd på dataset analysen

# %%
cat("Hur längd på dataset påverkar resultat:")
A2_3_1920_144.6_1920
A2_3_1920_144.6_1961
A2_3_1920_144.6_1920
A2_3_1961_144.6_1961
# Out:
# Hur längd på dataset påverkar resultat:
# $type
# [1] "Dataset: df_A2_1920, Threshold: 144.6, Year PR & I: 1920, 2024: No, Trend: mu sigma, Kovariat: GMST"
#
# $P1
# [1] 0.00235786
#
# $P0
# [1] 0.00055263
#
# $PR
# [1] 4.26663
#
# $delta_I
# [1] 26.44354
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A2_1920, Threshold: 144.6, Year PR & I: 1961, 2024: No, Trend: mu sigma, Kovariat: GMST"
#
# $P1
# [1] 0.00235786
#
# $P0
# [1] 0.00081668
#
# $PR
# [1] 2.88714
#
# $delta_I
# [1] 19.11387
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A2_1920, Threshold: 144.6, Year PR & I: 1920, 2024: No, Trend: mu sigma, Kovariat: GMST"
#
# $P1
# [1] 0.00235786
#
# $P0
# [1] 0.00055263
#
# $PR
# [1] 4.26663
#
# $delta_I
# [1] 26.44354
#
# $Parametrar
# [1] NA
# $type
# [1] "Dataset: df_A2_1961, Threshold: 144.6, Year PR & I: 1961, 2024: No, Trend: mu sigma, Kovariat: GMST"
#
# $P1
# [1] 0.00360427
#
# $P0
# [1] 0.00064354
#
# $PR
# [1] 5.60073
#
# $delta_I
# [1] 33.85242
#
# $Parametrar
# ...
